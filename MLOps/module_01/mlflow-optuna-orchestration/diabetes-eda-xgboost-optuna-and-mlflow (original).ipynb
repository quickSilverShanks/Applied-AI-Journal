# %% [markdown]
# <h1>Predicting Diabetes: A Machine Learning Approach</h1>

# %% [markdown]
# <div style="background-color:rgba(120,120,120,0.2);padding:15px;border-radius:10px;">
# <div>Diabetes, a chronic medical condition characterized by elevated blood sugar levels, has become a global health concern with a significant impact on individuals and healthcare systems. According to the World Health Organization (WHO), an estimated 422 million people worldwide were living with diabetes in 2014, and the prevalence is expected to rise.</div>
# </div>

# %% [markdown]
# <div style="background-color:rgba(120,120,120,0.2);padding:15px;border-radius:10px;">
# <div>This Jupyter Notebook aims to explore and predict diabetes using a machine learning model. The dataset used for this analysis contains various health metrics and lifestyle factors. Through exploratory data analysis (EDA), we will get insights about the relationships between different features and their influence on the likelihood of diabetes. After generating the model, it will be deployed as a web app to predict the probability of a user having diabetes.</div>
# </div>

# %% [markdown]
# <h1 style="font-size:20px;">About the dataset:</h1>
# <ul>
#     <li>
#         <code>gender</code>: Gender refers to the biological sex of the individual, which can have an impact on their susceptibility to diabetes. There are three categories in it male ,female and other.
#     </li>
#     <br>
#     <li>
#         <code>age</code>: Age is an important factor as diabetes is more commonly diagnosed in older adults.Age ranges from 0-80 in our dataset.
#     </li>
#     <br>
#     <li>
#         <code>hypertension</code>: Hypertension is a medical condition in which the blood pressure in the arteries is persistently elevated. It has values a 0 or 1 where 0 indicates they don’t have hypertension and for 1 it means they have hypertension.
#     </li>
#     <br>
#     <li>
#         <code>heart_disease</code>: Heart disease is another medical condition that is associated with an increased risk of developing diabetes. It has values a 0 or 1 where 0 indicates they don’t have heart disease and for 1 it means they have heart disease.
#     </li>
#     <br>
#     <li>
#         <code>smoking_history</code>: Smoking history is also considered a risk factor for diabetes and can exacerbate the complications associated with diabetes.In our dataset we have 5 categories i.e not current,former,No Info,current,never and ever.
#     </li>
#     <br>
#     <li>
#         <code>bmi</code>: BMI (Body Mass Index) is a measure of body fat based on weight and height. Higher BMI values are linked to a higher risk of diabetes. The range of BMI in the dataset is from 10.16 to 71.55. BMI less than 18.5 is underweight, 18.5-24.9 is normal, 25-29.9 is overweight, and 30 or more is obese.
#     </li>
#     <br>
#     <li>
#         <code>HbA1c_level</code>: HbA1c (Hemoglobin A1c) level is a measure of a person's average blood sugar level over the past 2-3 months. Higher levels indicate a greater risk of developing diabetes. Mostly more than 6.5% of HbA1c Level indicates diabetes.
#     </li>
#     <br>
#     <li>
#         <code>blood_glucose_level</code>: Blood glucose level refers to the amount of glucose in the bloodstream at a given time. High blood glucose levels are a key indicator of diabetes.
#     </li>
#     <br>
#     <li>
#         <code>diabetes</code>: Diabetes is the target variable being predicted, with values of 1 indicating the presence of diabetes and 0 indicating the absence of diabetes.
#     </li>
# </ul>
# <p>The dataset can be found at <a href='https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset'>https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset</a></p>
# <hr>

# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /opt/conda/lib/python3.10/site-packages (2.9.2)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.10/site-packages (from mlflow) (2.2.1)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /opt/conda/lib/python3.10/site-packages (from mlflow) (0.18.0)
# Requirement already satisfied: entrypoints<1 in /opt/conda/lib/python3.10/site-packages (from mlflow) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.1.32)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.10/site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.20.3)
# Requirement already satisfied: pytz<2024 in /opt/conda/lib/python3.10/site-packages (from mlflow) (2023.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.10/site-packages (from mlflow) (2.31.0)
# Requirement already satisfied: packaging<24 in /opt/conda/lib/python3.10/site-packages (from mlflow) (21.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (6.8.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (0.4.4)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.10/site-packages (from mlflow) (1.13.0)
# Requirement already satisfied: docker<7,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (6.1.3)
# Requirement already satisfied: Flask<4 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: numpy<2 in /opt/conda/lib/python3.10/site-packages (from mlflow) (1.24.3)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.10/site-packages (from mlflow) (1.11.4)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.10/site-packages (from mlflow) (2.0.3)
# Requirement already satisfied: querystring-parser<2 in /opt/conda/lib/python3.10/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (2.0.20)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.10/site-packages (from mlflow) (1.2.2)
# Requirement already satisfied: pyarrow<15,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (14.0.1)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.4.4)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.7.4)
# Requirement already satisfied: gunicorn<22 in /opt/conda/lib/python3.10/site-packages (from mlflow) (21.2.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.0)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (4.5.0)
# Requirement already satisfied: pyjwt>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (2.8.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (0.9.0)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.26.7 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.26.15)
# Requirement already satisfied: websocket-client>=0.32.0 in /opt/conda/lib/python3.10/site-packages (from docker<7,>=4.0.0->mlflow) (1.6.2)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow) (1.7.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython<4,>=2.1.0->mlflow) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.16.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3->mlflow) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (3.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (2.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow) (5.0.0)

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import pickle
import umap
from sklearn.preprocessing import StandardScaler, RobustScaler, OrdinalEncoder, LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, roc_auc_score, precision_score, recall_score
from sklearn.model_selection import cross_val_score, train_test_split, StratifiedKFold
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
import mlflow
import optuna

# Seed for random number generation
SEED = 101

plt.style.use('ggplot')

# %% [markdown]
# <h1 id = "EDA">Exploratory Data Analysis</h1>

# %%
# Reading the data
df = pd.read_csv('/kaggle/input/diabetes-prediction-dataset/diabetes_prediction_dataset.csv')

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.shape
# Out:
# (100000, 9)

# %% [markdown]
# <div>There are 100000 rows and 9 columns</div>

# %%
# Categorical features
cat_features = ['gender','smoking_history']

# Binary features
bin_features = ['hypertension','heart_disease']

# Numerical features
num_features = df.drop(columns=cat_features + bin_features + ['diabetes']).columns.tolist()


# Target variable
target = 'diabetes'

print(cat_features,'\n', num_features, '\n', '\n', bin_features, target)
# Out:
# ['gender', 'smoking_history']
#  ['age', 'bmi', 'HbA1c_level', 'blood_glucose_level']
#
#  ['hypertension', 'heart_disease'] diabetes

# %% [markdown]
# <h2>Checking missing data and duplicated values</h2>

# %%
# Checking missind data per column
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %% [markdown]
# <div>None of the columns have missing data</div>
# <div>The command above just showed that there are no NaN values in the dataset. We saw in the <code>df.head()</code> command that the <code>smoking_history</code> column has a <i>No Info</i> value. This will be addressed later</div>

# %% [markdown]
# <h2>Checking duplicated data</h2>

# %%
# Counting how many rows are duplicated
df.duplicated().sum()
# Out:
# 3854

# %%
# Getting the dataframe without duplicated rows
df = df.drop_duplicates()

# %%
# The new dataframe shape
df.shape
# Out:
# (96146, 9)

# %% [markdown]
# <h2>Checking the unique values for the columns</h2>

# %%
# Unique values for gender
df['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
# Unique values for smoking_history
df['smoking_history'].unique()
# Out:
# array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#       dtype=object)

# %% [markdown]
# <div>We have two categories that must be dealt with: <code>Other</code> for <code>gender</code> and <code>No Info</code> for <code>smoking_history</code></div>
# <div>In order to take a decision, it is necessary to calculate the proportion of this values in their respective feature</div>

# %%
# Checking the proportion of the category 'Other' for the gender feature
df['gender'].value_counts(normalize=True)
# Out:
# gender
# Female    0.584122
# Male      0.415691
# Other     0.000187
# Name: proportion, dtype: float64

# %% [markdown]
# <div>The category <code>Other</code> represents only 0.0187% of the values. Since it is a very small part, it will be dropped</div>

# %%
# Dropping rows with 'Other'
df = df.query("gender != 'Other'").reset_index(drop=True)

# %%
# Checking the proportion of the category 'No Info' for the smoking_history feature
df['smoking_history'].value_counts(normalize=True)
# Out:
# smoking_history
# never          0.357804
# No Info        0.342054
# former         0.096736
# current        0.095675
# not current    0.066151
# ever           0.041580
# Name: proportion, dtype: float64

# %% [markdown]
# <div>The category <code>No Info</code> represents 34.2% of the <code>smoking_history</code> values. Since it is a large part of the instances for the column <code>smoking_history</code>, assigning a value to the category might have a big impact on the results. It will be considered as a valid category

# %% [markdown]
# <h2>Checking the distribution of the target and the features</h2>

# %% [markdown]
# <h3>Categorical Features</h3>

# %%
# Checking the proportion of diabetes
df['diabetes'].value_counts(normalize=True)
# Out:
# diabetes
# 0    0.911763
# 1    0.088237
# Name: proportion, dtype: float64

# %%
# Plotting diabetes distribution
plt.figure(figsize=(5,4))
sns.countplot(data=df,x='diabetes',width=0.3)
# Out:
# <Axes: xlabel='diabetes', ylabel='count'>

# %% [markdown]
# <div>We can see that the dataset is unbalanced, with diabetes representing 8.8% of the instances. This unbalance can cause problems when developing the machine learning model, as the model might learn just to predict the majority class. The issue of imbalance will be addressed during the model development phase.</div>

# %% [markdown]
# <h2>Feature <code>gender</code><h2>

# %%
# Proportion for Male and Female
df['gender'].value_counts(normalize=True)
# Out:
# gender
# Female    0.584231
# Male      0.415769
# Name: proportion, dtype: float64

# %%
# Checking the diabetes for gender
df[['gender','diabetes']].groupby(by='gender').agg(['mean','count'])
# Out:
#         diabetes
#             mean  count
# gender
# Female  0.079183  56161
# Male    0.100958  39967

# %%
# Plotting gender distribution
plt.figure(figsize=(5,4))
sns.countplot(data=df,x='gender',width=0.3, hue='diabetes')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# <div>Diabetes occurrence was higher among <i>Males</i> (10%) when compared with <i>Females</i> (7%)</div>

# %% [markdown]
# <h2>Feature <code>hypertension</code><h2>

# %%
# Proportion for hypertension
df['hypertension'].value_counts(normalize=True)
# Out:
# hypertension
# 0    0.922385
# 1    0.077615
# Name: proportion, dtype: float64

# %%
# Checking the diabetes mean and count for hypertension
df[['hypertension','diabetes']].groupby(by='hypertension').agg(['mean','count'])
# Out:
#               diabetes
#                   mean  count
# hypertension
# 0             0.072135  88667
# 1             0.279587   7461

# %%
# Plotting hypertension distribution
plt.figure(figsize=(5,4))
sns.countplot(data=df,x='hypertension',width=0.3, hue='diabetes')
# Out:
# <Axes: xlabel='hypertension', ylabel='count'>

# %% [markdown]
# <div>Diabetes occurrence was higher among people with <code>hypertension</code> (28%) when compared with people without <code>hypertension</code> (7%)</div>

# %% [markdown]
# <h2>Feature <code>heart_disease</code><h2>

# %%
# Proportion for heart_disease
df['heart_disease'].value_counts(normalize=True)
# Out:
# heart_disease
# 0    0.95919
# 1    0.04081
# Name: proportion, dtype: float64

# %%
# Checking the diabetes mean and count for heart_disease
df[['heart_disease','diabetes']].groupby(by='heart_disease').agg(['mean','count'])
# Out:
#                diabetes
#                    mean  count
# heart_disease
# 0              0.078250  92205
# 1              0.322967   3923

# %%
# Plotting hypertension distribution
plt.figure(figsize=(5,4))
sns.countplot(data=df,x='heart_disease',width=0.3, hue='diabetes')
# Out:
# <Axes: xlabel='heart_disease', ylabel='count'>

# %% [markdown]
# <div>Diabetes occurrence was higher among people with <code>heart_disease</code> (32%) when compared with people without <code>heart_disease</code> (7.8%)</div>

# %% [markdown]
# <h2>Feature <code>smoking_history</code><h2>

# %%
# Proportion for smoking_history
df['smoking_history'].value_counts(normalize=True)
# Out:
# smoking_history
# never          0.357804
# No Info        0.342054
# former         0.096736
# current        0.095675
# not current    0.066151
# ever           0.041580
# Name: proportion, dtype: float64

# %%
# Checking the diabetes mean and count for smoking_history
df[['smoking_history','diabetes']].groupby(by='smoking_history').agg(['mean','count'])
# Out:
#                  diabetes
#                      mean  count
# smoking_history
# No Info          0.043946  32881
# current          0.103077   9197
# ever             0.118089   3997
# former           0.170986   9299
# never            0.097020  34395
# not current      0.108508   6359

# %%
# Plotting smoking_history distribution
plt.figure(figsize=(5,4))
sns.countplot(data=df,x='smoking_history',width=0.3, hue='diabetes')
# Out:
# <Axes: xlabel='smoking_history', ylabel='count'>

# %% [markdown]
# <div>
# The cateogry <code>No Info</code> had the lowest occurrence of diabetes (4.3%). This shows that assigning this category to other class among the others could cause a big change on the diabetes prediction. Former smokers were the ones with higher occurrence of diabetes (17%)
# </div>

# %% [markdown]
# <h3>Numerical Features</h3>

# %% [markdown]
# <h2>Feature <code>age</code></h2>

# %%
# Plotting age distribution
fig, ax = plt.subplots(figsize=(10,5),nrows=1, ncols=2)
sns.histplot(data=df,x='age', hue='diabetes',ax=ax[0],kde=True)
sns.boxplot(data=df, y='age', hue='diabetes', ax=ax[1], width=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div>The boxplot shows us that the people with diabetes have a median <code>age</code> higher than those without diabetes and the interquantile distance for is narrower for people with diabetes</div>

# %% [markdown]
# <h2>Feature <code>bmi</code></h2>

# %%
# Plotting bmi distribution
fig, ax = plt.subplots(figsize=(10,5),nrows=1, ncols=2)
sns.histplot(data=df,x='bmi', hue='diabetes',ax=ax[0],kde=True,bins=20)
sns.boxplot(data=df, y='bmi', hue='diabetes', ax=ax[1], width=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div>The boxplot shows us that the people with diabetes have a median <code>bmi</code> higher than those without diabetes.</div>

# %% [markdown]
# <h2>Feature <code>blood_glucose_level</code></h2>

# %%
# Plotting blood_glucose_level distribution
fig, ax = plt.subplots(figsize=(10,5),nrows=1, ncols=2)
sns.histplot(data=df,x='blood_glucose_level', hue='diabetes',ax=ax[0],kde=True,bins=20)
sns.boxplot(data=df, y='blood_glucose_level', hue='diabetes', ax=ax[1], width=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div>The boxplot shows us that the people with diabetes have a median <code>blood_glucose_level</code> higher than those without diabetes.</div>
# <div>It's also interesting to note that nobody from the non-diabetic group had <code>blood_glucose_level</code> higher than 200 .</div>

# %% [markdown]
# <h2>Feature <code>HbA1c_level</code></h2>

# %%
# Plotting blood_glucose_level distribution
fig, ax = plt.subplots(figsize=(10,5),nrows=1, ncols=2)
sns.histplot(data=df,x='HbA1c_level', hue='diabetes',ax=ax[0],kde=True,bins=20)
sns.boxplot(data=df, y='HbA1c_level', hue='diabetes', ax=ax[1], width=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div>The boxplot shows us that the people with diabetes have a median <code>HbA1c_level</code> higher than those without diabetes.</div>
# <div>It's interesting to note that nobody from the non-diabetic group had an <code>HbA1c_level</code> higher than approximately 7.</div>

# %% [markdown]
# <div>The features related to glucose,<code>blood_glucose_level</code> and <code>HbA1c_level</code>, showed the highest separation between people regarding diabetes. This makes sense, given that diabetes is related to abnormal glucose levels in the bloodstream.</div>

# %% [markdown]
# <div>The only feature that showed potential outliers was <code>bmi</code>. But the values represented as dots in the boxplot are possible to happen and should not be considered as outliers.</div>
# <hr>

# %% [markdown]
# <h2>Correlation Matrix</h2>

# %%
# Dataframe with numerical features
df_num_features = df[num_features + ['diabetes']]

# Dataframe with binary features
df_bin_features = df[bin_features]

# Using pandas get_dummies method for the categorical variables
df_cat_features_encoded = pd.concat([pd.get_dummies(df[cat_feature],prefix=cat_feature) for cat_feature in df.drop(columns=num_features+bin_features+['diabetes']).columns.tolist()],axis=1)

# Concatenating all dataframes
df_all_features = pd.concat([df_num_features, df_bin_features, df_cat_features_encoded], axis=1)

df_all_features.head()
# Out:
#     age    bmi  HbA1c_level  blood_glucose_level  diabetes  hypertension  \
# 0  80.0  25.19          6.6                  140         0             0
# 1  54.0  27.32          6.6                   80         0             0
# 2  28.0  27.32          5.7                  158         0             0
# 3  36.0  23.45          5.0                  155         0             0
# 4  76.0  20.14          4.8                  155         0             1
#
#    heart_disease  gender_Female  gender_Male  smoking_history_No Info  \
# 0              1           True        False                    False
# 1              0           True        False                     True
# 2              0          False         True                    False
# 3              0           True        False                    False
# 4              1          False         True                    False
#
#    smoking_history_current  smoking_history_ever  smoking_history_former  \
# 0                    False                 False                   False
# 1                    False                 False                   False
# 2                    False                 False                   False
# 3                     True                 False                   False
# 4                     True                 False                   False
#
#    smoking_history_never  smoking_history_not current
# 0                   True                        False
# 1                  False                        False
# 2                   True                        False
# 3                  False                        False
# 4                  False                        False

# %%
correlation_matrix = df_all_features.corr()
plt.figure(figsize=(10,7))
sns.heatmap(data=correlation_matrix, annot=True, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# <div>
#     <ul>
#         <li>
#             <code>HbA1c_level</code> is the highest correlated feature with diabetes, confirming what was showes in its boxplot.
#         </li>
#         <li>
#             <code>smoking_history_No info</code> has a large negative correlation with <code>smoking_history_never</code>. This suggests that the <code>No info</code> could possibly mean that the person has no smoking history.
#         </li>
#         <li>
#             For now <code>No info</code> will still be treated as a valid category
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 id="umap">Visualizing data with UMAP</h2>

# %% [markdown]
# <div>• UMAP, which stands for Uniform Manifold Approximation and Projection, is a powerful dimensionality reduction technique used for visualizing high-dimensional data in a lower-dimensional space. It is particularly effective for preserving both local and global structures of the data, making it a popular choice in machine learning and data analysis.</div>
# <div>• We are going to use UMAP to visualize our dataset in a 2D space and look for patterns that can differentiate people with diabtes from those without diabetes</div>
# <div>• For this machine learning project I will be using tree-based algorithms. Tree-based methods don't necessarily require feature scaling. So I will not scale the features before applying umap trasnformations.</div>

# %%
# The reducer that will project the dataset onto a 2D space
reducer = umap.UMAP(n_jobs=-1,random_state=SEED)

# %%
# Unscaled features
df_unscaled_umap = df_all_features.drop(columns='diabetes')

# %%
# Embedding the data into the 2D space
embedding = reducer.fit_transform(df_unscaled_umap)

# %%
# Creating a dataframe with the embedded data and identifying each instance with its respective diabetes label
df_diabetes_umap = pd.DataFrame(data=embedding,columns=['u0','u1'])
df_diabetes_umap['diabetes'] = df_all_features['diabetes']

# %%
# Plotting the data
sns.scatterplot(data=df_diabetes_umap,x='u0', y='u1', hue='diabetes',s=4)
# Out:
# <Axes: xlabel='u0', ylabel='u1'>

# %% [markdown]
# <div>We can see that there are some cluster with a high density of diabetes (blue dots)</div>

# %% [markdown]
# <h1>Model</h1>

# %% [markdown]
# <h1>Model Training and Optimization</h1>
#
# <p>In this notebook, I employed the following steps for training and optimizing the machine learning model:</p>
#
# <ol>
#   <li><strong>Model Selection:</strong> I chose XGBoost as the machine learning model for predicting diabetes, considering its effectiveness in handling complex relationships in data.</li>
#   <br>
#   <li><strong>Validation Strategy - Stratified K-fold Cross-Validation:</strong> To ensure robust model evaluation, I employed a Stratified K-fold cross-validation approach. This method maintains the distribution of target classes in each fold, especially important when dealing with imbalanced datasets like ours.</li>
#   <br>
#
#   <li><strong>Hyperparameter Optimization with Optuna:</strong> To enhance the model's performance, I utilized Optuna for hyperparameter optimization. Optuna systematically explores hyperparameter spaces to find the optimal set of parameters for the XGBoost model.</li>
#   <br>
#
#   <li><strong>Experiment Tracking with MLflow:</strong> I integrated MLflow for experiment tracking. MLflow allows me to log and organize experiments, making it easier to reproduce results and compare different model versions.</li>
#   <br>
#
#   <li><strong>Handling Imbalanced Dataset - scale_pos_weight Parameter:</strong> Given the imbalanced nature of the dataset, where the majority class (non-diabetic) significantly outnumbers the minority class (diabetic), I specifically tuned the <code>scale_pos_weight</code> parameter in XGBoost. This parameter helps address class imbalance during training by assigning higher weights to the minority class, allowing the model to better capture patterns related to diabetes.</li>
#   <br>
# </ol>
#
# <h2>About MLflow</h2>
#
# <p>MLflow is an open-source platform that simplifies the end-to-end machine learning lifecycle. It provides tools for tracking experiments, packaging code into reproducible runs, and sharing and deploying models. By leveraging MLflow, I ensure transparency and reproducibility in my machine learning experiments.</p>
#
# <p>Feel free to explore the MLflow UI to delve deeper into the tracked experiments and compare model performance across different configurations.</p>
#
# <p>The XGBoost model and its optimized hyperparameters will be serialized to be used by the API.</p>

# %%
# Variables
X = df.drop(columns=['diabetes'])

# Target
y = df['diabetes']

# %%
# Creating the folds for the k fold cross-validation
kfold = StratifiedKFold(n_splits=5 , shuffle=True, random_state=SEED)

# %%
# Create the column transformer to handle the feature transformations
column_transformer = ColumnTransformer(
    [
        ('num','passthrough',num_features),
        ('cat',OrdinalEncoder(),cat_features),
        ('bin','passthrough', bin_features)
    ],
    remainder='drop',
    verbose_feature_names_out=True
)

# %%
# Function to create a classification pipeline for different models
def create_classification_pipeline(classifier_model):

    pipeline = Pipeline(
        [
            ('transformer',column_transformer),
            ('classifier',classifier_model)
        ]
    )
    return pipeline

# %%
def flatten_array(predictions):
    flat_array = []
    for array in predictions:
        for item in array:
            flat_array.append(item)
    return flat_array

# %% [markdown]
# <h2>Stratified k-Fold Cross-Validation and Confusion Matrix Construction</h2>
#
# <ul>
#   <li>
#     <p>In this project, a robust validation strategy, namely stratified k-fold cross-validation, was employed to assess the performance of the machine learning model, ensuring reliable and unbiased evaluation.</p>
#   </li>
#   <li>
#     <p>Stratified k-fold cross-validation is particularly useful when dealing with imbalanced datasets, as it maintains the distribution of the target variable within each fold.</p>
#   </li>
#   <li>
#     <p>The dataset was divided into k (in this case, k=5) folds while preserving the proportion of diabetic and non-diabetic instances in each fold.</p>
#   </li>
#   <li>
#     <p>During each iteration of the cross-validation process, one fold was used as the validation set, and the model was trained on the remaining folds. This process was repeated k times, with each fold serving as the validation set exactly once.</p>
#   </li>
#   <li>
#     <p>The confusion matrix, a crucial evaluation metric for classification models, was constructed using the out-of-fold predictions.</p>
#   </li>
#   <li>
#     <p>For each iteration of the cross-validation, the predictions on the validation set were collected, and a fold-specific confusion matrix was computed.</p>
#   </li>
#   <li>
#     <p>By summing the true positive, false positive, true negative, and false negative values across all folds, an aggregate confusion matrix was obtained, providing a comprehensive overview of the model's performance across different folds.</p>
#   </li>
#   <li>
#     <p>This approach allowed for a thorough assessment of the model's ability to correctly classify instances into true positives, true negatives, false positives, and false negatives.</p>
#   </li>
#   <li>
#     <p>The out-of-fold predictions were also utilized to calculate essential metrics, including accuracy, precision, recall, and ROC AUC.</p>
#   </li>
#   <li>
#     <p>These metrics provide a detailed understanding of the model's overall performance and its ability to correctly identify positive and negative instances.</p>
#   </li>
#   <li>
#     <p>The combination of stratified k-fold cross-validation, aggregated confusion matrix, and comprehensive metric analysis ensures a robust evaluation of the machine learning model's performance on the diabetes prediction task.</p>
#   </li>
# </ul>

# %%
true_positives = []
false_positives = []
true_negatives = []
false_negatives = []
predictions_bin = []
predictions_proba = []
y_true = []

for i, (train_index, test_index) in enumerate(kfold.split(X,y)):

    X_train, y_train = X.loc[train_index], y.loc[train_index]
    X_test, y_test = X.loc[test_index], y.loc[test_index]

    classifer_model = XGBClassifier(random_state=SEED)
    
    pipeline_classifier = create_classification_pipeline(classifer_model)

    pipeline_classifier.fit(X_train, y_train)

    binary_predictions = pipeline_classifier.predict(X_test)
    proba_predictions = pipeline_classifier.predict_proba(X_test)

    predictions_bin.append(binary_predictions)
    predictions_proba.append(proba_predictions[:,1])
    y_true.append(y_test.to_numpy())

    fold_confusion_matrix = confusion_matrix(y_true=y_test, y_pred=binary_predictions)

    true_positives.append(fold_confusion_matrix[1,1])
    true_negatives.append(fold_confusion_matrix[0,0])
    false_positives.append(fold_confusion_matrix[0,1])
    false_negatives.append(fold_confusion_matrix[1,0])

predictions_bin = flatten_array(predictions_bin)
predictions_proba = flatten_array(predictions_proba)
y_true = flatten_array(y_true)


all_folds_confusion_matrix = np.array(
    [
        [np.sum(true_negatives),np.sum(false_positives)],
        [np.sum(false_negatives),np.sum(true_positives)]
    ]
)


ConfusionMatrixDisplay(all_folds_confusion_matrix).plot()
plt.grid(visible=False)

# %%
#Calculating the other metrics
roc_auc_kfold = roc_auc_score(y_true=y_true, y_score=predictions_proba)
accuracy_kfold = accuracy_score(y_true=y_true, y_pred=predictions_bin)
precision_kfold = precision_score(y_true=y_true, y_pred=predictions_bin)
recall_kfold = recall_score(y_true=y_true, y_pred=predictions_bin)

# %%
plt.style.use('default')

# %%
def objective(trial):

    with mlflow.start_run(nested=True):

        param = {
            "verbosity": 0,

            "objective": "binary:logistic",

            # defines booster, gblinear for linear functions.
            "booster": "gbtree",

            # L2 regularization weight.
            "reg_lambda": trial.suggest_float("reg_lambda", 1e-4, 1.0, log=True),

            # L1 regularization weight.
            "reg_alpha": trial.suggest_float("reg_alpha", 1e-4, 1.0, log=True),

            # sampling ratio for training data.
            "subsample": trial.suggest_float("subsample", 0.5, 1.0,step=0.1),

            # sampling according to each tree.
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 1.0),

            "n_estimators": trial.suggest_int("n_estimators",100,800,step=50),

            # maximum depth of the tree, signifies complexity of the tree.
            "max_depth":trial.suggest_int("max_depth", 2, 8, step=2),

            # minimum child weight, larger the term more conservative the tree.
            'min_child_weight':trial.suggest_int("min_child_weight", 2, 30),

            "eta":trial.suggest_float("eta", 1e-3, 1.0, log=True),

            # defines how selective algorithm is.
            "gamma":trial.suggest_float("gamma", 1e-3, 1.0, log=True),

            "grow_policy":trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"]),

            "scale_pos_weight":trial.suggest_float("scale_pos_weight",1,10)

        }

        true_positives = []
        false_positives = []
        true_negatives = []
        false_negatives = []
        predictions_bin = []
        predictions_proba = []
        y_true = []

        for i, (train_index, test_index) in enumerate(kfold.split(X,y)):

            X_train, y_train = X.loc[train_index], y.loc[train_index]
            X_test, y_test = X.loc[test_index], y.loc[test_index]

            classifer_model = XGBClassifier(**param, random_state=SEED)
            pipeline_classifier = create_classification_pipeline(classifer_model)

            pipeline_classifier.fit(X_train, y_train)

            binary_predictions = pipeline_classifier.predict(X_test)
            proba_predictions = pipeline_classifier.predict_proba(X_test)

            predictions_bin.append(binary_predictions)
            predictions_proba.append(proba_predictions[:,1])
            y_true.append(y_test.to_numpy())

            fold_confusion_matrix = confusion_matrix(y_true=y_test, y_pred=binary_predictions)

            true_positives.append(fold_confusion_matrix[1,1])
            true_negatives.append(fold_confusion_matrix[0,0])
            false_positives.append(fold_confusion_matrix[0,1])
            false_negatives.append(fold_confusion_matrix[1,0])

        predictions_bin = flatten_array(predictions_bin)
        predictions_proba = flatten_array(predictions_proba)
        y_true = flatten_array(y_true)

        accuracy = accuracy_score(y_true=y_true, y_pred=predictions_bin)
        recall = recall_score(y_true=y_true, y_pred=predictions_bin)
        precision = precision_score(y_true=y_true, y_pred=predictions_bin)
        roc_auc = roc_auc_score(y_true=y_true, y_score=predictions_proba)

        mlflow.log_metric('accuracy',accuracy)
        mlflow.log_metric('recall',recall)
        mlflow.log_metric('precision',precision)
        mlflow.log_metric('roc_auc',roc_auc)
        mlflow.log_param('params',param)

        return roc_auc

# %%
study = None
def run_experiments():

    mlflow.set_experiment("XGBoost_tuning_final_version")

    with mlflow.start_run(nested=True) as parent_run:
        mlflow.autolog(log_models=True)
        study = optuna.create_study(direction='maximize')
        study.optimize(objective, n_trials=50)

        print("Number of finished trials: ", len(study.trials))
        print("Best trial:")
        trial = study.best_trial

        print("  Value: {}".format(trial.value))
        print("  Params: ")
        for key, value in trial.params.items():
            print("    {}: {}".format(key, value))    

run_experiments()
# Out:
# 2024/01/08 00:56:43 INFO mlflow.tracking.fluent: Experiment with name 'XGBoost_tuning_final_version' does not exist. Creating a new experiment.
# 2024/01/08 00:56:43 INFO mlflow.tracking.fluent: Autologging successfully enabled for tensorflow.
# 2024/01/08 00:56:43 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2024/01/08 00:56:44 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2024/01/08 00:56:46 INFO mlflow.tracking.fluent: Autologging successfully enabled for statsmodels.
# [I 2024-01-08 00:56:46,737] A new study created in memory with name: no-name-8d8470f0-0c87-4b57-931a-5ba411d8b0fa
# [I 2024-01-08 00:57:42,578] Trial 0 finished with value: 0.9745965001285988 and parameters: {'reg_lambda': 0.5909315937076262, 'reg_alpha': 0.012183519249302945, 'subsample': 0.7, 'colsample_bytree': 0.92225565751536, 'n_estimators': 550, 'max_depth': 6, 'min_child_weight': 2, 'eta': 0.001397188821084454, 'gamma': 0.7237216545524232, 'grow_policy': 'depthwise', 'scale_pos_weight': 9.136206046361679}. Best is trial 0 with value: 0.9745965001285988.
# [I 2024-01-08 00:58:29,509] Trial 1 finished with value: 0.9793193960734944 and parameters: {'reg_lambda': 0.3649414055914246, 'reg_alpha': 0.21512918109717935, 'subsample': 0.7, 'colsample_bytree': 0.8746819079162462, 'n_estimators': 500, 'max_depth': 4, 'min_child_weight': 7, 'eta': 0.03216758095463784, 'gamma': 0.010837766503895925, 'grow_policy': 'lossguide', 'scale_pos_weight': 1.9612179930894165}. Best is trial 1 with value: 0.9793193960734944.
# [I 2024-01-08 00:59:15,029] Trial 2 finished with value: 0.9767190440044977 and parameters: {'reg_lambda': 0.00019736151774062707, 'reg_alpha': 0.0007213430523196835, 'subsample': 0.7, 'colsample_bytree': 0.5203061164269711, 'n_estimators': 450, 'max_depth': 4, 'min_child_weight': 6, 'eta': 0.011383398354971016, 'gamma': 0.0027038812751771554, 'grow_policy': 'depthwise', 'scale_pos_weight': 2.1475065038843084}. Best is trial 1 with value: 0.9793193960734944.
# [I 2024-01-08 00:59:53,293] Trial 3 finished with value: 0.969672496690038 and parameters: {'reg_lambda': 0.055138794768452924, 'reg_alpha': 0.0001788472774101184, 'subsample': 0.5, 'colsample_bytree': 0.22771089710774373, 'n_estimators': 350, 'max_depth': 4, 'min_child_weight': 30, 'eta': 0.009985750221545646, 'gamma': 0.06497354216511927, 'grow_policy': 'depthwise', 'scale_pos_weight': 4.343745335536695}. Best is trial 1 with value: 0.9793193960734944.
# [I 2024-01-08 01:00:41,144] Trial 4 finished with value: 0.9699774501769387 and parameters: {'reg_lambda': 0.0009148139349025142, 'reg_alpha': 0.006074568775544957, 'subsample': 0.5, 'colsample_bytree': 0.4916739701299504, 'n_estimators': 500, 'max_depth': 4, 'min_child_weight': 5, 'eta': 0.7806224328473418, 'gamma': 0.0013856945220113678, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.034258170112437}. Best is trial 1 with value: 0.9793193960734944.
# [I 2024-01-08 01:01:24,771] Trial 5 finished with value: 0.9727780818018431 and parameters: {'reg_lambda': 0.33013591667025777, 'reg_alpha': 0.0002437409594457004, 'subsample': 1.0, 'colsample_bytree': 0.42919229344470333, 'n_estimators': 300, 'max_depth': 6, 'min_child_weight': 27, 'eta': 0.003917742019991017, 'gamma': 0.45046697373630856, 'grow_policy': 'depthwise', 'scale_pos_weight': 9.162692054248884}. Best is trial 1 with value: 0.9793193960734944.
# [I 2024-01-08 01:01:58,033] Trial 6 finished with value: 0.9749311840465522 and parameters: {'reg_lambda': 0.00035776947502836064, 'reg_alpha': 0.0004511165371954083, 'subsample': 0.9, 'colsample_bytree': 0.7520973571340326, 'n_estimators': 100, 'max_depth': 4, 'min_child_weight': 18, 'eta': 0.028097490727299362, 'gamma': 0.11859228466019153, 'grow_policy': 'lossguide', 'scale_pos_weight': 8.541090129401937}. Best is trial 1 with value: 0.9793193960734944.
# [I 2024-01-08 01:02:43,639] Trial 7 finished with value: 0.9764797639394628 and parameters: {'reg_lambda': 0.18632178206213554, 'reg_alpha': 0.4311858281399292, 'subsample': 0.8, 'colsample_bytree': 0.9949418203943041, 'n_estimators': 350, 'max_depth': 6, 'min_child_weight': 27, 'eta': 0.1273487812435514, 'gamma': 0.2799324746828367, 'grow_policy': 'depthwise', 'scale_pos_weight': 4.400309513194509}. Best is trial 1 with value: 0.9793193960734944.
# [I 2024-01-08 01:03:22,006] Trial 8 finished with value: 0.9761434974564864 and parameters: {'reg_lambda': 0.01033527890490363, 'reg_alpha': 0.07321945132645438, 'subsample': 0.7, 'colsample_bytree': 0.8727714366759023, 'n_estimators': 300, 'max_depth': 4, 'min_child_weight': 6, 'eta': 0.01582350673129753, 'gamma': 0.0011970042611952458, 'grow_policy': 'depthwise', 'scale_pos_weight': 7.93336125103013}. Best is trial 1 with value: 0.9793193960734944.
# [I 2024-01-08 01:04:15,692] Trial 9 finished with value: 0.9722042550238119 and parameters: {'reg_lambda': 0.7308416665000026, 'reg_alpha': 0.003538853329578775, 'subsample': 0.7, 'colsample_bytree': 0.9901247998147589, 'n_estimators': 350, 'max_depth': 8, 'min_child_weight': 22, 'eta': 0.2175654380071127, 'gamma': 0.0014844509000846299, 'grow_policy': 'lossguide', 'scale_pos_weight': 8.273401008265738}. Best is trial 1 with value: 0.9793193960734944.
# [I 2024-01-08 01:05:03,128] Trial 10 finished with value: 0.9790512989319757 and parameters: {'reg_lambda': 0.021863645689753283, 'reg_alpha': 0.5060708541169316, 'subsample': 0.6, 'colsample_bytree': 0.6910003100059623, 'n_estimators': 800, 'max_depth': 2, 'min_child_weight': 12, 'eta': 0.10366823620415883, 'gamma': 0.009799542760393892, 'grow_policy': 'lossguide', 'scale_pos_weight': 1.2375171277111288}. Best is trial 1 with value: 0.9793193960734944.
# [I 2024-01-08 01:05:49,775] Trial 11 finished with value: 0.9791365987159025 and parameters: {'reg_lambda': 0.015980854960441163, 'reg_alpha': 0.9797524968944326, 'subsample': 0.6, 'colsample_bytree': 0.7335677467877226, 'n_estimators': 800, 'max_depth': 2, 'min_child_weight': 12, 'eta': 0.08949966116382244, 'gamma': 0.011088159267998499, 'grow_policy': 'lossguide', 'scale_pos_weight': 1.0500489956443477}. Best is trial 1 with value: 0.9793193960734944.
# [I 2024-01-08 01:06:37,396] Trial 12 finished with value: 0.9793744805010045 and parameters: {'reg_lambda': 0.0026807254473014894, 'reg_alpha': 0.985781157233258, 'subsample': 0.6, 'colsample_bytree': 0.7970090514647383, 'n_estimators': 800, 'max_depth': 2, 'min_child_weight': 12, 'eta': 0.06421046859992179, 'gamma': 0.012927696706275476, 'grow_policy': 'lossguide', 'scale_pos_weight': 2.7010697836083963}. Best is trial 12 with value: 0.9793744805010045.
# [I 2024-01-08 01:07:19,045] Trial 13 finished with value: 0.9793897129415637 and parameters: {'reg_lambda': 0.0018181547930547026, 'reg_alpha': 0.11809902105212336, 'subsample': 0.6, 'colsample_bytree': 0.8167784285399624, 'n_estimators': 650, 'max_depth': 2, 'min_child_weight': 11, 'eta': 0.03910759604589945, 'gamma': 0.015768057928181187, 'grow_policy': 'lossguide', 'scale_pos_weight': 3.090394514684156}. Best is trial 13 with value: 0.9793897129415637.
# [I 2024-01-08 01:08:02,619] Trial 14 finished with value: 0.9775368702945527 and parameters: {'reg_lambda': 0.00272190882201583, 'reg_alpha': 0.06839842010674996, 'subsample': 0.6, 'colsample_bytree': 0.6391073310011419, 'n_estimators': 700, 'max_depth': 2, 'min_child_weight': 14, 'eta': 0.5110510477348614, 'gamma': 0.02344165134316783, 'grow_policy': 'lossguide', 'scale_pos_weight': 3.2856793165200675}. Best is trial 13 with value: 0.9793897129415637.
# [I 2024-01-08 01:08:46,258] Trial 15 finished with value: 0.9794247802419137 and parameters: {'reg_lambda': 0.003203919023664476, 'reg_alpha': 0.08871584114845277, 'subsample': 0.5, 'colsample_bytree': 0.7856920493353944, 'n_estimators': 650, 'max_depth': 2, 'min_child_weight': 20, 'eta': 0.05372224873506586, 'gamma': 0.004330273523725102, 'grow_policy': 'lossguide', 'scale_pos_weight': 6.56587492353013}. Best is trial 15 with value: 0.9794247802419137.
# [I 2024-01-08 01:09:28,929] Trial 16 finished with value: 0.9785774858244009 and parameters: {'reg_lambda': 0.00204607069840495, 'reg_alpha': 0.02844071528003298, 'subsample': 0.5, 'colsample_bytree': 0.5739944738072751, 'n_estimators': 600, 'max_depth': 2, 'min_child_weight': 20, 'eta': 0.26288629399190255, 'gamma': 0.004209845073934656, 'grow_policy': 'lossguide', 'scale_pos_weight': 6.732647827418096}. Best is trial 15 with value: 0.9794247802419137.
# [I 2024-01-08 01:10:38,048] Trial 17 finished with value: 0.9786819438593579 and parameters: {'reg_lambda': 0.00010661596880921347, 'reg_alpha': 0.09397189164310475, 'subsample': 0.5, 'colsample_bytree': 0.8266607544601852, 'n_estimators': 650, 'max_depth': 8, 'min_child_weight': 23, 'eta': 0.005528696158184429, 'gamma': 0.0044692882848512165, 'grow_policy': 'lossguide', 'scale_pos_weight': 5.8715964414002}. Best is trial 15 with value: 0.9794247802419137.
# [I 2024-01-08 01:11:24,243] Trial 18 finished with value: 0.9794025564016893 and parameters: {'reg_lambda': 0.0007666872673266716, 'reg_alpha': 0.017356549977619755, 'subsample': 0.8, 'colsample_bytree': 0.6561404445798684, 'n_estimators': 700, 'max_depth': 2, 'min_child_weight': 16, 'eta': 0.039752856283331424, 'gamma': 0.04085698951391833, 'grow_policy': 'lossguide', 'scale_pos_weight': 7.200239592921309}. Best is trial 15 with value: 0.9794247802419137.
# [I 2024-01-08 01:12:06,169] Trial 19 finished with value: 0.9704915746390421 and parameters: {'reg_lambda': 0.0003620213548037785, 'reg_alpha': 0.0020396215642123103, 'subsample': 0.9, 'colsample_bytree': 0.3515455246711032, 'n_estimators': 700, 'max_depth': 2, 'min_child_weight': 17, 'eta': 0.0010016793117247744, 'gamma': 0.04753292163001617, 'grow_policy': 'lossguide', 'scale_pos_weight': 6.976316252705287}. Best is trial 15 with value: 0.9794247802419137.
# [I 2024-01-08 01:12:51,203] Trial 20 finished with value: 0.9785946949579486 and parameters: {'reg_lambda': 0.005286994365154265, 'reg_alpha': 0.02429091028044697, 'subsample': 0.8, 'colsample_bytree': 0.6487206097424504, 'n_estimators': 700, 'max_depth': 2, 'min_child_weight': 24, 'eta': 0.21758207914706967, 'gamma': 0.14013948061220127, 'grow_policy': 'lossguide', 'scale_pos_weight': 6.9728047046464985}. Best is trial 15 with value: 0.9794247802419137.
# [I 2024-01-08 01:13:32,049] Trial 21 finished with value: 0.9793382960563696 and parameters: {'reg_lambda': 0.000919020246810102, 'reg_alpha': 0.1613794060037697, 'subsample': 0.8, 'colsample_bytree': 0.7756696282925998, 'n_estimators': 600, 'max_depth': 2, 'min_child_weight': 10, 'eta': 0.04232000736687467, 'gamma': 0.03061886313931611, 'grow_policy': 'lossguide', 'scale_pos_weight': 6.045910972947706}. Best is trial 15 with value: 0.9794247802419137.
# [I 2024-01-08 01:14:15,063] Trial 22 finished with value: 0.9780009896028612 and parameters: {'reg_lambda': 0.0009437088154781647, 'reg_alpha': 0.025980100640538704, 'subsample': 0.9, 'colsample_bytree': 0.6981674869275925, 'n_estimators': 650, 'max_depth': 2, 'min_child_weight': 15, 'eta': 0.021756247958975607, 'gamma': 0.019488422465442856, 'grow_policy': 'lossguide', 'scale_pos_weight': 7.740033513166309}. Best is trial 15 with value: 0.9794247802419137.
# [I 2024-01-08 01:15:01,738] Trial 23 finished with value: 0.9794467168933303 and parameters: {'reg_lambda': 0.005410269873959508, 'reg_alpha': 0.042260309652126696, 'subsample': 0.6, 'colsample_bytree': 0.5810496585985326, 'n_estimators': 750, 'max_depth': 2, 'min_child_weight': 19, 'eta': 0.0478925179391045, 'gamma': 0.005461443263612969, 'grow_policy': 'lossguide', 'scale_pos_weight': 3.8255550009435724}. Best is trial 23 with value: 0.9794467168933303.
# [I 2024-01-08 01:15:56,081] Trial 24 finished with value: 0.9783560962096872 and parameters: {'reg_lambda': 0.006251428734321581, 'reg_alpha': 0.009254083336647493, 'subsample': 0.5, 'colsample_bytree': 0.5793125075071919, 'n_estimators': 750, 'max_depth': 4, 'min_child_weight': 19, 'eta': 0.06460951802583, 'gamma': 0.0040436771574512845, 'grow_policy': 'lossguide', 'scale_pos_weight': 4.983703418338017}. Best is trial 23 with value: 0.9794467168933303.
# [I 2024-01-08 01:16:42,454] Trial 25 finished with value: 0.9794531964646985 and parameters: {'reg_lambda': 0.036739218193994345, 'reg_alpha': 0.03900128491483348, 'subsample': 1.0, 'colsample_bytree': 0.42295138481509387, 'n_estimators': 750, 'max_depth': 2, 'min_child_weight': 21, 'eta': 0.0634660211738263, 'gamma': 0.00617718053636572, 'grow_policy': 'lossguide', 'scale_pos_weight': 6.332777525955472}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:17:35,256] Trial 26 finished with value: 0.9785364393472331 and parameters: {'reg_lambda': 0.04752908832669287, 'reg_alpha': 0.06351267512553513, 'subsample': 1.0, 'colsample_bytree': 0.342626118893276, 'n_estimators': 750, 'max_depth': 4, 'min_child_weight': 21, 'eta': 0.14414745057876485, 'gamma': 0.006412798418715469, 'grow_policy': 'lossguide', 'scale_pos_weight': 3.884500203749959}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:18:19,788] Trial 27 finished with value: 0.9786075101699946 and parameters: {'reg_lambda': 0.05516577779737697, 'reg_alpha': 0.05016224700821958, 'subsample': 1.0, 'colsample_bytree': 0.4330665798396477, 'n_estimators': 750, 'max_depth': 2, 'min_child_weight': 25, 'eta': 0.34894615889015146, 'gamma': 0.0022162104955629797, 'grow_policy': 'lossguide', 'scale_pos_weight': 6.158709128972993}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:19:19,001] Trial 28 finished with value: 0.9784613418280026 and parameters: {'reg_lambda': 0.027486573641724254, 'reg_alpha': 0.25124800293808597, 'subsample': 0.6, 'colsample_bytree': 0.29942625667015776, 'n_estimators': 600, 'max_depth': 6, 'min_child_weight': 20, 'eta': 0.06480380201856188, 'gamma': 0.006456763621267884, 'grow_policy': 'lossguide', 'scale_pos_weight': 5.384077076954805}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:20:00,731] Trial 29 finished with value: 0.9750399176301069 and parameters: {'reg_lambda': 0.09975066058480582, 'reg_alpha': 0.008518533488722514, 'subsample': 0.5, 'colsample_bytree': 0.49446730088626034, 'n_estimators': 550, 'max_depth': 2, 'min_child_weight': 26, 'eta': 0.007256832658384624, 'gamma': 0.0027488758772226257, 'grow_policy': 'lossguide', 'scale_pos_weight': 4.238227355432701}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:20:49,450] Trial 30 finished with value: 0.9734965777559352 and parameters: {'reg_lambda': 0.005430067692925183, 'reg_alpha': 0.04132389725242982, 'subsample': 0.9, 'colsample_bytree': 0.4306329935296228, 'n_estimators': 550, 'max_depth': 4, 'min_child_weight': 29, 'eta': 0.0035178944440271013, 'gamma': 0.0021526361564952455, 'grow_policy': 'lossguide', 'scale_pos_weight': 9.991408262957059}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:21:34,757] Trial 31 finished with value: 0.97942583281916 and parameters: {'reg_lambda': 0.011442538746606853, 'reg_alpha': 0.018638905909353836, 'subsample': 0.8, 'colsample_bytree': 0.6320302065464485, 'n_estimators': 750, 'max_depth': 2, 'min_child_weight': 16, 'eta': 0.052906453001694435, 'gamma': 0.046569249835182985, 'grow_policy': 'lossguide', 'scale_pos_weight': 6.551080558837944}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:22:19,014] Trial 32 finished with value: 0.9767038922727369 and parameters: {'reg_lambda': 0.010960923176619173, 'reg_alpha': 0.013795807635077362, 'subsample': 1.0, 'colsample_bytree': 0.6018624366492186, 'n_estimators': 750, 'max_depth': 2, 'min_child_weight': 18, 'eta': 0.016269186842175095, 'gamma': 0.006406381697279182, 'grow_policy': 'lossguide', 'scale_pos_weight': 6.150883723803028}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:23:05,831] Trial 33 finished with value: 0.9794376109231461 and parameters: {'reg_lambda': 0.030811159839049685, 'reg_alpha': 0.003626431972651904, 'subsample': 0.7, 'colsample_bytree': 0.5273647589427929, 'n_estimators': 800, 'max_depth': 2, 'min_child_weight': 22, 'eta': 0.054718878381803726, 'gamma': 0.07983316143851288, 'grow_policy': 'lossguide', 'scale_pos_weight': 6.649679350864305}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:24:03,144] Trial 34 finished with value: 0.9793421277065756 and parameters: {'reg_lambda': 0.032543492398973035, 'reg_alpha': 0.0015166717674630727, 'subsample': 0.7, 'colsample_bytree': 0.542793190306619, 'n_estimators': 800, 'max_depth': 4, 'min_child_weight': 22, 'eta': 0.02698104838315294, 'gamma': 0.11970373501284716, 'grow_policy': 'lossguide', 'scale_pos_weight': 7.4787456589288475}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:24:36,006] Trial 35 finished with value: 0.9781176985608486 and parameters: {'reg_lambda': 0.10232482092791134, 'reg_alpha': 0.005070903692656076, 'subsample': 0.7, 'colsample_bytree': 0.46726687012427487, 'n_estimators': 100, 'max_depth': 2, 'min_child_weight': 14, 'eta': 0.1502962580843409, 'gamma': 0.070525557241199, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.398166913311975}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:25:20,856] Trial 36 finished with value: 0.9786883931649268 and parameters: {'reg_lambda': 0.018902428353095392, 'reg_alpha': 0.0027273511621777095, 'subsample': 0.7, 'colsample_bytree': 0.5454516802301762, 'n_estimators': 450, 'max_depth': 4, 'min_child_weight': 16, 'eta': 0.0859182056792093, 'gamma': 0.07743294244654195, 'grow_policy': 'lossguide', 'scale_pos_weight': 4.931556236877913}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:26:14,347] Trial 37 finished with value: 0.979222027633907 and parameters: {'reg_lambda': 0.08330271057716622, 'reg_alpha': 0.0010698471490630558, 'subsample': 0.8, 'colsample_bytree': 0.37628595399874754, 'n_estimators': 750, 'max_depth': 4, 'min_child_weight': 24, 'eta': 0.018317723783065367, 'gamma': 0.9747046847893518, 'grow_policy': 'depthwise', 'scale_pos_weight': 6.483848911957758}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:26:58,363] Trial 38 finished with value: 0.9735617844119167 and parameters: {'reg_lambda': 0.19275563371462848, 'reg_alpha': 0.005504324086943332, 'subsample': 0.9, 'colsample_bytree': 0.21038885289512976, 'n_estimators': 800, 'max_depth': 2, 'min_child_weight': 3, 'eta': 0.012386169500493623, 'gamma': 0.17072794448567677, 'grow_policy': 'lossguide', 'scale_pos_weight': 8.931355983010597}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:27:33,975] Trial 39 finished with value: 0.9761681291091977 and parameters: {'reg_lambda': 0.007800107285849748, 'reg_alpha': 0.01772436440579567, 'subsample': 0.7, 'colsample_bytree': 0.2662144974417116, 'n_estimators': 150, 'max_depth': 6, 'min_child_weight': 18, 'eta': 0.029196897504584825, 'gamma': 0.23173862749469132, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.6745583062548555}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:28:19,073] Trial 40 finished with value: 0.9793294261594208 and parameters: {'reg_lambda': 0.03872855852543659, 'reg_alpha': 0.04163785130417406, 'subsample': 0.8, 'colsample_bytree': 0.5095570967070651, 'n_estimators': 500, 'max_depth': 4, 'min_child_weight': 8, 'eta': 0.04450592238123336, 'gamma': 0.39701447368479675, 'grow_policy': 'lossguide', 'scale_pos_weight': 3.8054185727483825}. Best is trial 25 with value: 0.9794531964646985.
# [I 2024-01-08 01:29:03,277] Trial 41 finished with value: 0.9794536168230238 and parameters: {'reg_lambda': 0.014057361434063637, 'reg_alpha': 0.22951318777936996, 'subsample': 0.6, 'colsample_bytree': 0.46378802170916145, 'n_estimators': 700, 'max_depth': 2, 'min_child_weight': 20, 'eta': 0.0591333795386007, 'gamma': 0.05038154194714027, 'grow_policy': 'lossguide', 'scale_pos_weight': 6.512068708260342}. Best is trial 41 with value: 0.9794536168230238.
# [I 2024-01-08 01:29:48,714] Trial 42 finished with value: 0.9793644477247849 and parameters: {'reg_lambda': 0.011904723770679427, 'reg_alpha': 0.23453912975912491, 'subsample': 0.6, 'colsample_bytree': 0.4656505056661743, 'n_estimators': 700, 'max_depth': 2, 'min_child_weight': 22, 'eta': 0.08221117985829864, 'gamma': 0.04940202550508878, 'grow_policy': 'lossguide', 'scale_pos_weight': 7.34354306797162}. Best is trial 41 with value: 0.9794536168230238.
# [I 2024-01-08 01:30:34,449] Trial 43 finished with value: 0.9792864090424244 and parameters: {'reg_lambda': 0.016045965808652786, 'reg_alpha': 0.008968760789266854, 'subsample': 0.6, 'colsample_bytree': 0.3874496579399397, 'n_estimators': 750, 'max_depth': 2, 'min_child_weight': 19, 'eta': 0.1026455556179385, 'gamma': 0.08108799749578573, 'grow_policy': 'lossguide', 'scale_pos_weight': 8.0752126704212}. Best is trial 41 with value: 0.9794536168230238.
# [I 2024-01-08 01:31:21,095] Trial 44 finished with value: 0.9790353475105368 and parameters: {'reg_lambda': 0.06771872476684677, 'reg_alpha': 0.41690692364884724, 'subsample': 0.7, 'colsample_bytree': 0.6080015775044288, 'n_estimators': 800, 'max_depth': 2, 'min_child_weight': 21, 'eta': 0.02375047468367489, 'gamma': 0.02654681189649424, 'grow_policy': 'lossguide', 'scale_pos_weight': 4.694735786948826}. Best is trial 41 with value: 0.9794536168230238.
# [I 2024-01-08 01:32:05,877] Trial 45 finished with value: 0.9787916318244542 and parameters: {'reg_lambda': 0.026801711242271594, 'reg_alpha': 0.13636645097111416, 'subsample': 0.6, 'colsample_bytree': 0.5364923600227323, 'n_estimators': 700, 'max_depth': 2, 'min_child_weight': 28, 'eta': 0.17452088593262957, 'gamma': 0.0422361725344535, 'grow_policy': 'depthwise', 'scale_pos_weight': 2.153012770068969}. Best is trial 41 with value: 0.9794536168230238.
# [I 2024-01-08 01:33:30,840] Trial 46 finished with value: 0.9773364609319941 and parameters: {'reg_lambda': 0.014551700603482461, 'reg_alpha': 0.0004270346597603372, 'subsample': 0.7, 'colsample_bytree': 0.46962736824894896, 'n_estimators': 800, 'max_depth': 8, 'min_child_weight': 14, 'eta': 0.035240908937917044, 'gamma': 0.009037090267283542, 'grow_policy': 'lossguide', 'scale_pos_weight': 6.45920556900122}. Best is trial 41 with value: 0.9794536168230238.
# [I 2024-01-08 01:34:16,319] Trial 47 finished with value: 0.9794077190744963 and parameters: {'reg_lambda': 0.17531374746987466, 'reg_alpha': 0.03303401775302422, 'subsample': 0.6, 'colsample_bytree': 0.6943563490104919, 'n_estimators': 750, 'max_depth': 2, 'min_child_weight': 17, 'eta': 0.05496415517841209, 'gamma': 0.016673227584324074, 'grow_policy': 'lossguide', 'scale_pos_weight': 5.618437206595439}. Best is trial 41 with value: 0.9794536168230238.
# [I 2024-01-08 01:35:00,935] Trial 48 finished with value: 0.9792607920697988 and parameters: {'reg_lambda': 0.004076982915248808, 'reg_alpha': 0.003762008214348998, 'subsample': 0.6, 'colsample_bytree': 0.4046007765014555, 'n_estimators': 650, 'max_depth': 2, 'min_child_weight': 23, 'eta': 0.1130448267324195, 'gamma': 0.097238144718534, 'grow_policy': 'lossguide', 'scale_pos_weight': 7.546458542826615}. Best is trial 41 with value: 0.9794536168230238.
# [I 2024-01-08 01:35:38,123] Trial 49 finished with value: 0.9794001660761088 and parameters: {'reg_lambda': 0.008253654360187324, 'reg_alpha': 0.013597875404140463, 'subsample': 0.7, 'colsample_bytree': 0.5613175700862998, 'n_estimators': 200, 'max_depth': 4, 'min_child_weight': 26, 'eta': 0.07566821340832745, 'gamma': 0.03428665962164486, 'grow_policy': 'lossguide', 'scale_pos_weight': 8.406425458888869}. Best is trial 41 with value: 0.9794536168230238.
# Number of finished trials:  50
# Best trial:
#   Value: 0.9794536168230238
#   Params:
#     reg_lambda: 0.014057361434063637
#     reg_alpha: 0.22951318777936996
#     subsample: 0.6
#     colsample_bytree: 0.46378802170916145
#     n_estimators: 700
#     max_depth: 2
#     min_child_weight: 20
#     eta: 0.0591333795386007
#     gamma: 0.05038154194714027
#     grow_policy: lossguide
#     scale_pos_weight: 6.512068708260342

# %%
# Best parameters found by optuna
best_params = {
    'reg_lambda':0.014057361434063637,
    'reg_alpha': 0.22951318777936996,
    'subsample': 0.6,
    'colsample_bytree': 0.46378802170916145,
    'n_estimators': 700,
    'max_depth': 2,
    'min_child_weight': 20,
    'eta': 0.0591333795386007,
    'gamma': 0.05038154194714027,
    'grow_policy': 'lossguide',
    'scale_pos_weight': 6.512068708260342
}

# %%
final_model = XGBClassifier(**best_params, random_state=SEED)

final_pipeline_classifier = create_classification_pipeline(final_model)

final_pipeline_classifier.fit(X, y)
# Out:
# 2024/01/08 01:38:13 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '53e85241f6344421870906e9d9857e96', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   ['age', 'bmi', 'HbA1c_level',
#                                                    'blood_glucose_level']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['gender',
#                                                    'smoking_history']),
#                                                  ('bin', 'passthrough',
#                                                   ['hypertension',
#                                                    'heart_disease'])])),
#                 ('classifier',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsampl...
#                                gamma=0.05038154194714027,
#                                grow_policy='lossguide', importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=2, max_leaves=None,
#                                min_child_weight=20, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=700, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
final_classifier = final_pipeline_classifier[-1]
final_transformer = final_pipeline_classifier[0]

# %% [markdown]
# <p>The feature importances show what was already noted during the EDA: the features related to blood glucose levels are the ones with more predicting power.</p>

# %%
dict_feature_importances = {'feature':final_transformer.get_feature_names_out(), 'importance':final_classifier.feature_importances_}
df_feature_importances = pd.DataFrame.from_dict(dict_feature_importances).sort_values(by='importance',ascending=False)
df_feature_importances
# Out:
#                     feature  importance
# 2          num__HbA1c_level    0.435015
# 3  num__blood_glucose_level    0.285866
# 0                  num__age    0.114943
# 6         bin__hypertension    0.057201
# 1                  num__bmi    0.045459
# 7        bin__heart_disease    0.037879
# 5      cat__smoking_history    0.014450
# 4               cat__gender    0.009189

# %% [markdown]
# <h2>Serializing the model</h2>

# %%
# Serializing the model so it can be used with the API
with open('diabetes_model','wb') as model:
    pickle.dump(final_pipeline_classifier,model)
