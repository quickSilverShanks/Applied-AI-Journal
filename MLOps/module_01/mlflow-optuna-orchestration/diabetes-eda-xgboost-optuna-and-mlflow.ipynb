# %% [markdown]
# <h2>Predicting Diabetes: A Machine Learning Approach</h1>

# %% [markdown]
# <div style="background-color:rgba(120,120,120,0.2);padding:15px;border-radius:10px;">
# <div>This Jupyter Notebook aims to explore and predict diabetes using a machine learning model. The dataset used for this analysis contains various health metrics and lifestyle factors. Through exploratory data analysis (EDA), we will get insights about the relationships between different features and their influence on the likelihood of diabetes. After generating the model, it will be deployed as a web app to predict the probability of a user having diabetes.</div>
# </div>

# %% [markdown]
# <h1 style="font-size:20px;">About the dataset:</h1>
# <ul>
#     <li>
#         <code>gender</code>: Gender refers to the biological sex of the individual, which can have an impact on their susceptibility to diabetes. There are three categories in it male ,female and other.
#     </li>
#     <br>
#     <li>
#         <code>age</code>: Age is an important factor as diabetes is more commonly diagnosed in older adults.Age ranges from 0-80 in our dataset.
#     </li>
#     <br>
#     <li>
#         <code>hypertension</code>: Hypertension is a medical condition in which the blood pressure in the arteries is persistently elevated. It has values a 0 or 1 where 0 indicates they don’t have hypertension and for 1 it means they have hypertension.
#     </li>
#     <br>
#     <li>
#         <code>heart_disease</code>: Heart disease is another medical condition that is associated with an increased risk of developing diabetes. It has values a 0 or 1 where 0 indicates they don’t have heart disease and for 1 it means they have heart disease.
#     </li>
#     <br>
#     <li>
#         <code>smoking_history</code>: Smoking history is also considered a risk factor for diabetes and can exacerbate the complications associated with diabetes.In our dataset we have 5 categories i.e not current,former,No Info,current,never and ever.
#     </li>
#     <br>
#     <li>
#         <code>bmi</code>: BMI (Body Mass Index) is a measure of body fat based on weight and height. Higher BMI values are linked to a higher risk of diabetes. The range of BMI in the dataset is from 10.16 to 71.55. BMI less than 18.5 is underweight, 18.5-24.9 is normal, 25-29.9 is overweight, and 30 or more is obese.
#     </li>
#     <br>
#     <li>
#         <code>HbA1c_level</code>: HbA1c (Hemoglobin A1c) level is a measure of a person's average blood sugar level over the past 2-3 months. Higher levels indicate a greater risk of developing diabetes. Mostly more than 6.5% of HbA1c Level indicates diabetes.
#     </li>
#     <br>
#     <li>
#         <code>blood_glucose_level</code>: Blood glucose level refers to the amount of glucose in the bloodstream at a given time. High blood glucose levels are a key indicator of diabetes.
#     </li>
#     <br>
#     <li>
#         <code>diabetes</code>: Diabetes is the target variable being predicted, with values of 1 indicating the presence of diabetes and 0 indicating the absence of diabetes.
#     </li>
# </ul>
# <p>The dataset can be found at <a href='https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset'>https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset</a></p>
# <hr>

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import pickle
import umap
from sklearn.preprocessing import StandardScaler, RobustScaler, OrdinalEncoder, LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, roc_auc_score, precision_score, recall_score
from sklearn.model_selection import cross_val_score, train_test_split, StratifiedKFold
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
import mlflow
import optuna

# Seed for random number generation
SEED = 101

plt.style.use('ggplot')

# %% [markdown]
# <h3 id = "EDA">Exploratory Data Analysis</h1>

# %%
# reading the data
df = pd.read_csv('./diabetes_prediction_dataset.csv')
print(df.shape)
df.head()
# Out:
# (100000, 9)
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %% [markdown]
# <div>There are 100000 rows and 9 columns</div>

# %%
# categorical features
cat_features = ['gender','smoking_history']

# binary features
bin_features = ['hypertension','heart_disease']

# numerical features
num_features = df.drop(columns=cat_features + bin_features + ['diabetes']).columns.tolist()


# target variable
target = 'diabetes'

print(cat_features, '\n', num_features, '\n', bin_features, '\n', target)
# Out:
# ['gender', 'smoking_history']
#  ['age', 'bmi', 'HbA1c_level', 'blood_glucose_level']
#  ['hypertension', 'heart_disease']
#  diabetes

# %% [markdown]
# <h3>Checking missing data and duplicated values</h2>

# %%
# checking missing data per column
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %% [markdown]
# <div>None of the columns have missing data</div>
# <div>The command above just showed that there are no NaN values in the dataset. We saw in the <code>df.head()</code> command that the <code>smoking_history</code> column has a <i>No Info</i> value. This will be addressed later</div>

# %%
# counting duplicate rows
df.duplicated().sum()
# Out:
# np.int64(3854)

# %%
# dropping duplicate rows
df = df.drop_duplicates()

# new dataframe
df.shape
# Out:
# (96146, 9)

# %% [markdown]
# <h3>Checking the unique values for the columns</h2>

# %%
# unique values for gender
df['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
# unique values for smoking_history
df['smoking_history'].unique()
# Out:
# array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#       dtype=object)

# %% [markdown]
# <div>We have two categories that must be dealt with: <code>Other</code> for <code>gender</code> and <code>No Info</code> for <code>smoking_history</code></div>
# <div>In order to take a decision, it is necessary to calculate the proportion of this values in their respective feature</div>

# %%
# checking proportion of category 'Other' for the gender feature
df['gender'].value_counts(normalize=True)
# Out:
# gender
# Female    0.584122
# Male      0.415691
# Other     0.000187
# Name: proportion, dtype: float64

# %% [markdown]
# <div>The category <code>Other</code> represents only 0.0187% of the values. Since it is a very small part, it will be dropped</div>

# %%
# dropping rows with 'Other'
df = df.query("gender != 'Other'").reset_index(drop=True)

# %%
# checking proportion of category 'No Info' for the smoking_history feature
df['smoking_history'].value_counts(normalize=True)
# Out:
# smoking_history
# never          0.357804
# No Info        0.342054
# former         0.096736
# current        0.095675
# not current    0.066151
# ever           0.041580
# Name: proportion, dtype: float64

# %% [markdown]
# <div>The category <code>No Info</code> represents 34.2% of the <code>smoking_history</code> values. Since it' i's a large part of the column <code>smoking_history</code>, assigning a value to this category might have a big impact on the results. It will be considered as a valid category.

# %% [markdown]
# <h3>Checking the distribution of the target and the features</h2>

# %% [markdown]
# <h4>Categorical Features</h3>

# %%
# Checking the proportion of diabetes
df['diabetes'].value_counts(normalize=True)
# Out:
# diabetes
# 0    0.911763
# 1    0.088237
# Name: proportion, dtype: float64

# %%
# Plotting diabetes distribution
plt.figure(figsize=(5,4))
sns.countplot(data=df,x='diabetes',width=0.3)
# Out:
# <Axes: xlabel='diabetes', ylabel='count'>

# %% [markdown]
# <div>We can see that the dataset is unbalanced, with diabetes representing 8.8% of the instances. This unbalance can cause problems when developing the machine learning model, as the model might learn just to predict the majority class. The issue of imbalance will be addressed during the model development phase.</div>

# %% [markdown]
# <h5>Feature <code>gender</code><h2>

# %%
# proportion for gender categories
df['gender'].value_counts(normalize=True)
# Out:
# gender
# Female    0.584231
# Male      0.415769
# Name: proportion, dtype: float64

# %%
# checking the diabetes across gender
df[['gender','diabetes']].groupby(by='gender').agg(['mean','count'])
# Out:
#         diabetes
#             mean  count
# gender
# Female  0.079183  56161
# Male    0.100958  39967

# %%
# plotting gender distribution
plt.figure(figsize=(5,4))
sns.countplot(data=df, x='gender', width=0.3, hue='diabetes')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# <div>Diabetes occurrence was higher among <i>Males</i> (10%) when compared with <i>Females</i> (8%)</div>

# %% [markdown]
# <h5>Feature <code>hypertension</code><h2>

# %%
# proportion for hypertension
df['hypertension'].value_counts(normalize=True)
# Out:
# hypertension
# 0    0.922385
# 1    0.077615
# Name: proportion, dtype: float64

# %%
# checking the diabetes mean and count for hypertension
df[['hypertension','diabetes']].groupby(by='hypertension').agg(['mean','count'])
# Out:
#               diabetes
#                   mean  count
# hypertension
# 0             0.072135  88667
# 1             0.279587   7461

# %%
# plotting hypertension distribution
plt.figure(figsize=(5,4))
sns.countplot(data=df, x='hypertension', width=0.3, hue='diabetes')
# Out:
# <Axes: xlabel='hypertension', ylabel='count'>

# %% [markdown]
# <div>Diabetes occurrence was higher among people with <code>hypertension</code> (28%) when compared with people without <code>hypertension</code> (7%)</div>

# %% [markdown]
# <h5>Feature <code>heart_disease</code><h2>

# %%
# proportion for heart_disease
df['heart_disease'].value_counts(normalize=True)
# Out:
# heart_disease
# 0    0.95919
# 1    0.04081
# Name: proportion, dtype: float64

# %%
# checking the diabetes mean and count for heart_disease
df[['heart_disease','diabetes']].groupby(by='heart_disease').agg(['mean','count'])
# Out:
#                diabetes
#                    mean  count
# heart_disease
# 0              0.078250  92205
# 1              0.322967   3923

# %%
# plotting hypertension distribution
plt.figure(figsize=(5,4))
sns.countplot(data=df,x='heart_disease',width=0.3, hue='diabetes')
# Out:
# <Axes: xlabel='heart_disease', ylabel='count'>

# %% [markdown]
# <div>Diabetes occurrence was higher among people with <code>heart_disease</code> (32%) when compared with people without <code>heart_disease</code> (7.8%)</div>

# %% [markdown]
# <h5>Feature <code>smoking_history</code><h2>

# %%
# proportion for smoking_history
df['smoking_history'].value_counts(normalize=True)
# Out:
# smoking_history
# never          0.357804
# No Info        0.342054
# former         0.096736
# current        0.095675
# not current    0.066151
# ever           0.041580
# Name: proportion, dtype: float64

# %%
# checking the diabetes mean and count for smoking_history
df[['smoking_history','diabetes']].groupby(by='smoking_history').agg(['mean','count'])
# Out:
#                  diabetes
#                      mean  count
# smoking_history
# No Info          0.043946  32881
# current          0.103077   9197
# ever             0.118089   3997
# former           0.170986   9299
# never            0.097020  34395
# not current      0.108508   6359

# %%
# plotting smoking_history distribution
plt.figure(figsize=(5,4))
sns.countplot(data=df,x='smoking_history',width=0.3, hue='diabetes')
# Out:
# <Axes: xlabel='smoking_history', ylabel='count'>

# %% [markdown]
# <div>
# The cateogry <code>No Info</code> had the lowest occurrence of diabetes (4.3%). This shows that assigning this category to other class among the others could cause a big change on the diabetes prediction. Former smokers were the ones with higher occurrence of diabetes (17%)
# </div>

# %% [markdown]
# <h4>Numerical Features</h3>

# %% [markdown]
# <h5>Feature <code>age</code></h2>

# %%
# plotting age distribution
fig, ax = plt.subplots(figsize=(10,5), nrows=1, ncols=2)
sns.histplot(data=df, x='age', hue='diabetes', ax=ax[0], kde=True)
sns.boxplot(data=df, y='age', hue='diabetes', ax=ax[1], width=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div>The boxplot shows us that the people with diabetes have a median <code>age</code> higher than those without diabetes and the interquantile distance for is narrower for people with diabetes</div>

# %% [markdown]
# <h5>Feature <code>bmi</code></h2>

# %%
# plotting bmi distribution
fig, ax = plt.subplots(figsize=(10,5), nrows=1, ncols=2)
sns.histplot(data=df, x='bmi', hue='diabetes', ax=ax[0], kde=True, bins=20)
sns.boxplot(data=df, y='bmi', hue='diabetes', ax=ax[1], width=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div>The boxplot shows us that the people with diabetes have a median <code>bmi</code> higher than those without diabetes.</div>

# %% [markdown]
# <h5>Feature <code>blood_glucose_level</code></h2>

# %%
# plotting blood_glucose_level distribution
fig, ax = plt.subplots(figsize=(10,5), nrows=1, ncols=2)
sns.histplot(data=df, x='blood_glucose_level', hue='diabetes',ax=ax[0], kde=True, bins=20)
sns.boxplot(data=df, y='blood_glucose_level', hue='diabetes', ax=ax[1], width=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div>The boxplot shows us that the people with diabetes have a median <code>blood_glucose_level</code> higher than those without diabetes.</div>
# <div>It's also interesting to note that nobody from the non-diabetic group had <code>blood_glucose_level</code> higher than 200 .</div>

# %% [markdown]
# <h5>Feature <code>HbA1c_level</code></h2>

# %%
# plotting blood_glucose_level distribution
fig, ax = plt.subplots(figsize=(10,5), nrows=1, ncols=2)
sns.histplot(data=df, x='HbA1c_level', hue='diabetes', ax=ax[0], kde=True, bins=20)
sns.boxplot(data=df, y='HbA1c_level', hue='diabetes', ax=ax[1], width=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div>The boxplot shows us that the people with diabetes have a median <code>HbA1c_level</code> higher than those without diabetes.</div>
# <div>It's interesting to note that nobody from the non-diabetic group had an <code>HbA1c_level</code> higher than approximately 7.</div>

# %% [markdown]
# <div>The features related to glucose,<code>blood_glucose_level</code> and <code>HbA1c_level</code>, showed the highest separation between people regarding diabetes. This makes sense, given that diabetes is related to abnormal glucose levels in the bloodstream.</div>

# %% [markdown]
# <div>The only feature that showed potential outliers was <code>bmi</code>. But the values represented as dots in the boxplot are possible to happen and should not be considered as outliers.</div>
# <hr>

# %% [markdown]
# <h3>Correlation Matrix</h2>

# %%
# dataframe with numerical features
df_num_features = df[num_features + ['diabetes']]

# dataframe with binary features
df_bin_features = df[bin_features]

# using pandas get_dummies method for the categorical variables
df_cat_features_encoded = pd.concat(
    [pd.get_dummies(df[cat_feature], prefix=cat_feature) for cat_feature in df.drop(columns=num_features+bin_features+['diabetes']).columns.tolist()],
    axis=1
    )

# concatenating all dataframes
df_all_features = pd.concat([df_num_features, df_bin_features, df_cat_features_encoded], axis=1)

df_all_features.head()
# Out:
#     age    bmi  HbA1c_level  blood_glucose_level  diabetes  hypertension  \
# 0  80.0  25.19          6.6                  140         0             0
# 1  54.0  27.32          6.6                   80         0             0
# 2  28.0  27.32          5.7                  158         0             0
# 3  36.0  23.45          5.0                  155         0             0
# 4  76.0  20.14          4.8                  155         0             1
#
#    heart_disease  gender_Female  gender_Male  smoking_history_No Info  \
# 0              1           True        False                    False
# 1              0           True        False                     True
# 2              0          False         True                    False
# 3              0           True        False                    False
# 4              1          False         True                    False
#
#    smoking_history_current  smoking_history_ever  smoking_history_former  \
# 0                    False                 False                   False
# 1                    False                 False                   False
# 2                    False                 False                   False
# 3                     True                 False                   False
# 4                     True                 False                   False
#
#    smoking_history_never  smoking_history_not current
# 0                   True                        False
# 1                  False                        False
# 2                   True                        False
# 3                  False                        False
# 4                  False                        False

# %%
correlation_matrix = df_all_features.corr()
plt.figure(figsize=(10,7))
sns.heatmap(data=correlation_matrix, cmap='coolwarm', annot=True, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# <div>
#     <ul>
#         <li>
#             <code>HbA1c_level</code> and <code>blood_glucose_level</code> are the highest correlated features with diabetes, confirming what was in their boxplots.
#         </li>
#         <li>
#             For now <code>No info</code> will still be treated as a valid category
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h3 id="umap">Visualizing data with UMAP</h2>

# %% [markdown]
# <div>• UMAP, which stands for Uniform Manifold Approximation and Projection, is a powerful dimensionality reduction technique used for visualizing high-dimensional data in a lower-dimensional space. It is particularly effective for preserving both local and global structures of the data, making it a popular choice in machine learning and data analysis.</div>
# <div>• We are going to use UMAP to visualize our dataset in a 2D space and look for patterns that can differentiate people with diabetes from those without diabetes</div>
# <div>• For this machine learning project I will be using tree-based algorithms. Tree-based methods don't necessarily require feature scaling. So I will not scale the features before applying umap transformations.</div>

# %%
# the reducer that will project the dataset onto a 2D space
reducer = umap.UMAP(n_jobs=-1, random_state=SEED)

# unscaled features
df_unscaled_umap = df_all_features.drop(columns='diabetes')

# embedding the data into the 2D space
embedding = reducer.fit_transform(df_unscaled_umap)

# creating a dataframe with the embedded data and identifying each instance with its respective diabetes label
df_diabetes_umap = pd.DataFrame(data=embedding, columns=['u0','u1'])
df_diabetes_umap['diabetes'] = df_all_features['diabetes']

# %%
# plotting the data
sns.scatterplot(data=df_diabetes_umap, x='u0', y='u1', hue='diabetes', s=4)
# Out:
# <Axes: xlabel='u0', ylabel='u1'>

# %% [markdown]
# <div>We can see that there are some cluster with a high density of diabetes (blue dots)</div>

# %% [markdown]
# <h2>Model Training and Optimization</h2>
#
# <p>In this notebook, I employ the following steps for training and optimizing the machine learning model:</p>
#
# <ol>
#   <li><strong>Model Selection:</strong> I choose XGBoost as the machine learning model for predicting diabetes, considering its effectiveness in handling complex relationships in data.</li>
#   <br>
#   <li><strong>Validation Strategy - Stratified K-fold Cross-Validation:</strong> To ensure robust model evaluation, I employ a Stratified K-fold cross-validation approach. This method maintains the distribution of target classes in each fold, especially important when dealing with imbalanced datasets like ours.</li>
#   <br>
#
#   <li><strong>Hyperparameter Optimization with Optuna:</strong> To enhance the model's performance, I use Optuna for hyperparameter optimization. Optuna systematically explores hyperparameter spaces to find the optimal set of parameters for the XGBoost model.</li>
#   <br>
#
#   <li><strong>Experiment Tracking with MLflow:</strong> I use MLflow for experiment tracking. MLflow allows me to log and organize experiments, making it easier to reproduce results and compare different model versions.</li>
#   <br>
#
#   <li><strong>Handling Imbalanced Dataset - scale_pos_weight Parameter:</strong> Given the imbalanced nature of the dataset, where the majority class (non-diabetic) significantly outnumbers the minority class (diabetic), I specifically tuned the <code>scale_pos_weight</code> parameter in XGBoost. This parameter helps address class imbalance during training by assigning higher weights to the minority class, allowing the model to better capture patterns related to diabetes.</li>
#   <br>
# </ol>
#
# <h3>About MLflow</h3>
#
# <p>MLflow is an open-source platform that simplifies the end-to-end machine learning lifecycle. It provides tools for tracking experiments, packaging code into reproducible runs, and sharing and deploying models. By leveraging MLflow, I ensure transparency and reproducibility in my machine learning experiments.</p>
#
# <p>Feel free to explore the MLflow UI to delve deeper into the tracked experiments and compare model performance across different configurations.</p>
#
# <p>The XGBoost model and its optimized hyperparameters will be serialized to be used by the API.</p>

# %%
# variables
X = df.drop(columns=['diabetes'])

# target
y = df['diabetes']

# creating the folds for the k fold cross-validation
kfold = StratifiedKFold(n_splits=5 , shuffle=True, random_state=SEED)

# create the column transformer to handle the feature transformations
column_transformer = ColumnTransformer(
    [
        ('num', 'passthrough', num_features),
        ('cat', OrdinalEncoder(), cat_features),
        ('bin', 'passthrough', bin_features)
    ],
    remainder='drop',
    verbose_feature_names_out=True
)

# %%
# helper function
def flatten_array(predictions):
    flat_array = []
    for array in predictions:
        for item in array:
            flat_array.append(item)
    return flat_array


# function to create a classification pipeline for different models
def create_classification_pipeline(classifier_model):

    pipeline = Pipeline(
        [
            ('transformer',column_transformer),
            ('classifier',classifier_model)
        ]
    )
    return pipeline

# %% [markdown]
# <h3>Stratified k-Fold Cross-Validation and Confusion Matrix Construction</h3>
#
# <ul>
#   <li>
#     <p>In this project, a robust validation strategy, namely stratified k-fold cross-validation, is employed to assess the performance of the machine learning model, ensuring reliable and unbiased evaluation.</p>
#   </li>
#   <li>
#     <p>Stratified k-fold cross-validation is particularly useful when dealing with imbalanced datasets, as it maintains the distribution of the target variable within each fold.</p>
#   </li>
#   <li>
#     <p>The dataset is divided into k (in this case, k=5) folds while preserving the proportion of diabetic and non-diabetic instances in each fold.</p>
#   </li>
#   <li>
#     <p>During each iteration of the cross-validation process, one fold is used as the validation set, and the model is trained on the remaining folds. This process is repeated k times, with each fold serving as the validation set exactly once.</p>
#   </li>
#   <li>
#     <p>The confusion matrix, a crucial evaluation metric for classification models, is constructed using the out-of-fold predictions.</p>
#   </li>
#   <li>
#     <p>For each iteration of the cross-validation, the predictions on the validation set were collected, and a fold-specific confusion matrix is computed.</p>
#   </li>
#   <li>
#     <p>By summing the true positive, false positive, true negative, and false negative values across all folds, an aggregate confusion matrix is obtained, providing a comprehensive overview of the model's performance across different folds.</p>
#   </li>
#   <li>
#     <p>This approach allowed for a thorough assessment of the model's ability to correctly classify instances into true positives, true negatives, false positives, and false negatives.</p>
#   </li>
#   <li>
#     <p>The out-of-fold predictions were also utilized to calculate essential metrics, including accuracy, precision, recall, and ROC AUC.</p>
#   </li>
#   <li>
#     <p>These metrics provide a detailed understanding of the model's overall performance and its ability to correctly identify positive and negative instances.</p>
#   </li>
#   <li>
#     <p>The combination of stratified k-fold cross-validation, aggregated confusion matrix, and comprehensive metric analysis ensures a robust evaluation of the machine learning model's performance on the diabetes prediction task.</p>
#   </li>
# </ul>

# %%
true_positives = []
false_positives = []
true_negatives = []
false_negatives = []
predictions_bin = []
predictions_proba = []
y_true = []


for i, (train_index, test_index) in enumerate(kfold.split(X, y)):

    X_train, y_train = X.loc[train_index], y.loc[train_index]
    X_test, y_test = X.loc[test_index], y.loc[test_index]

    classifer_model = XGBClassifier(random_state=SEED)
    
    pipeline_classifier = create_classification_pipeline(classifer_model)

    pipeline_classifier.fit(X_train, y_train)

    binary_predictions = pipeline_classifier.predict(X_test)
    proba_predictions = pipeline_classifier.predict_proba(X_test)

    predictions_bin.append(binary_predictions)
    predictions_proba.append(proba_predictions[:,1])
    y_true.append(y_test.to_numpy())

    fold_confusion_matrix = confusion_matrix(y_true=y_test, y_pred=binary_predictions)

    true_positives.append(fold_confusion_matrix[1,1])
    true_negatives.append(fold_confusion_matrix[0,0])
    false_positives.append(fold_confusion_matrix[0,1])
    false_negatives.append(fold_confusion_matrix[1,0])

predictions_bin = flatten_array(predictions_bin)
predictions_proba = flatten_array(predictions_proba)
y_true = flatten_array(y_true)


all_folds_confusion_matrix = np.array(
    [
        [np.sum(true_negatives), np.sum(false_positives)],
        [np.sum(false_negatives), np.sum(true_positives)]
    ]
)


ConfusionMatrixDisplay(all_folds_confusion_matrix).plot()
plt.grid(visible=False)

# %%
# calculating the other metrics
roc_auc_kfold = roc_auc_score(y_true=y_true, y_score=predictions_proba)
accuracy_kfold = accuracy_score(y_true=y_true, y_pred=predictions_bin)
precision_kfold = precision_score(y_true=y_true, y_pred=predictions_bin)
recall_kfold = recall_score(y_true=y_true, y_pred=predictions_bin)

print("roc_auc: ", roc_auc_kfold, "\naccuracy: ", accuracy_kfold, "\nprecision: ", precision_kfold, "\nrecall: ", recall_kfold)
# Out:
# roc_auc:  0.9769551690280869
# accuracy:  0.9699671271637816
# precision:  0.9556931096269751
# recall:  0.6917000707380335

# %%
plt.style.use('default')

# %%
def objective(trial):

    with mlflow.start_run(nested=True):

        param = {
            "verbosity": 0,

            "objective": "binary:logistic",

            # defines booster, gblinear for linear functions
            "booster": "gbtree",

            # L2 regularization weight
            "reg_lambda": trial.suggest_float("reg_lambda", 1e-4, 1.0, log=True),

            # L1 regularization weight
            "reg_alpha": trial.suggest_float("reg_alpha", 1e-4, 1.0, log=True),

            # sampling ratio for training data
            "subsample": trial.suggest_float("subsample", 0.5, 1.0, step=0.1),

            # sampling according to each tree.
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 1.0),

            "n_estimators": trial.suggest_int("n_estimators",100,800,step=50),

            # maximum depth of the tree, signifies complexity of the tree.
            "max_depth":trial.suggest_int("max_depth", 2, 8, step=2),

            # minimum child weight, larger the term more conservative the tree.
            'min_child_weight':trial.suggest_int("min_child_weight", 2, 30),

            "eta":trial.suggest_float("eta", 1e-3, 1.0, log=True),

            # defines how selective algorithm is.
            "gamma":trial.suggest_float("gamma", 1e-3, 1.0, log=True),

            "grow_policy":trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"]),

            "scale_pos_weight":trial.suggest_float("scale_pos_weight",1,10)

        }

        true_positives = []
        false_positives = []
        true_negatives = []
        false_negatives = []
        predictions_bin = []
        predictions_proba = []
        y_true = []

        for i, (train_index, test_index) in enumerate(kfold.split(X,y)):

            X_train, y_train = X.loc[train_index], y.loc[train_index]
            X_test, y_test = X.loc[test_index], y.loc[test_index]

            classifer_model = XGBClassifier(**param, random_state=SEED)
            pipeline_classifier = create_classification_pipeline(classifer_model)

            pipeline_classifier.fit(X_train, y_train)

            binary_predictions = pipeline_classifier.predict(X_test)
            proba_predictions = pipeline_classifier.predict_proba(X_test)

            predictions_bin.append(binary_predictions)
            predictions_proba.append(proba_predictions[:,1])
            y_true.append(y_test.to_numpy())

            fold_confusion_matrix = confusion_matrix(y_true=y_test, y_pred=binary_predictions)

            true_positives.append(fold_confusion_matrix[1,1])
            true_negatives.append(fold_confusion_matrix[0,0])
            false_positives.append(fold_confusion_matrix[0,1])
            false_negatives.append(fold_confusion_matrix[1,0])

        predictions_bin = flatten_array(predictions_bin)
        predictions_proba = flatten_array(predictions_proba)
        y_true = flatten_array(y_true)

        accuracy = accuracy_score(y_true=y_true, y_pred=predictions_bin)
        recall = recall_score(y_true=y_true, y_pred=predictions_bin)
        precision = precision_score(y_true=y_true, y_pred=predictions_bin)
        roc_auc = roc_auc_score(y_true=y_true, y_score=predictions_proba)

        mlflow.log_metric('accuracy', accuracy)
        mlflow.log_metric('recall', recall)
        mlflow.log_metric('precision', precision)
        mlflow.log_metric('roc_auc', roc_auc)
        mlflow.log_param('params', param)

        return roc_auc

# %%
study = None
def run_experiments():

    mlflow.set_experiment("XGBoost_tuning_final_version")

    with mlflow.start_run(nested=True) as parent_run:
        mlflow.autolog(log_models=True)
        study = optuna.create_study(direction='maximize')
        study.optimize(objective, n_trials=50)

        print("Number of finished trials: ", len(study.trials))
        print("Best trial:")
        trial = study.best_trial

        print("  Value: {}".format(trial.value))
        print("  Params: ")
        for key, value in trial.params.items():
            print("    {}: {}".format(key, value))    

run_experiments()
# Out:
# 2026/01/20 12:46:20 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.schemas
# 2026/01/20 12:46:20 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.tables
# 2026/01/20 12:46:20 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.types
# 2026/01/20 12:46:20 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.constraints
# 2026/01/20 12:46:20 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.defaults
# 2026/01/20 12:46:20 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.comments
# 2026/01/20 12:46:21 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/01/20 12:46:21 INFO mlflow.store.db.utils: Updating database tables
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# 2026/01/20 12:46:21 INFO alembic.runtime.migration: Running upgrade bf29a5ff90ea -> 1bd49d398cd23, add secrets tables
# 2026/01/20 12:46:22 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/20 12:46:22 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/20 12:46:22 INFO mlflow.tracking.fluent: Experiment with name 'XGBoost_tuning_final_version' does not exist. Creating a new experiment.
# 2026/01/20 12:46:22 WARNING mlflow.utils.git_utils: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Bad git executable.
# The git executable must be specified in one of the following ways:
#     - be included in your $PATH
#     - be set via $GIT_PYTHON_GIT_EXECUTABLE
#     - explicitly set via git.refresh(<full-path-to-git-executable>)
#
# All git commands will error until this is rectified.
#
# This initial message can be silenced or aggravated in the future by setting the
# $GIT_PYTHON_REFRESH environment variable. Use one of the following values:
#     - quiet|q|silence|s|silent|none|n|0: for no message or exception
#     - warn|w|warning|log|l|1: for a warning message (logging level CRITICAL, displayed by default)
#     - error|e|exception|raise|r|2: for a raised exception
#
# Example:
#     export GIT_PYTHON_REFRESH=quiet
#
# 2026/01/20 12:46:33 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/01/20 12:46:33 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# [I 2026-01-20 12:46:33,270] A new study created in memory with name: no-name-17c5d182-219a-4f64-9e6d-2d397d84d220
# [I 2026-01-20 12:46:56,577] Trial 0 finished with value: 0.9740631447775465 and parameters: {'reg_lambda': 0.03793422591681594, 'reg_alpha': 0.061461125912909406, 'subsample': 0.8, 'colsample_bytree': 0.3574717458707095, 'n_estimators': 700, 'max_depth': 6, 'min_child_weight': 19, 'eta': 0.43018948771054166, 'gamma': 0.18151431201061002, 'grow_policy': 'lossguide', 'scale_pos_weight': 6.699994898152865}. Best is trial 0 with value: 0.9740631447775465.
# [I 2026-01-20 12:47:14,393] Trial 1 finished with value: 0.9725868517199607 and parameters: {'reg_lambda': 0.06122021135313015, 'reg_alpha': 0.0047253850106121435, 'subsample': 0.7, 'colsample_bytree': 0.7393112187555144, 'n_estimators': 500, 'max_depth': 2, 'min_child_weight': 15, 'eta': 0.005323786780779861, 'gamma': 0.17577392167020658, 'grow_policy': 'lossguide', 'scale_pos_weight': 8.776441357830272}. Best is trial 0 with value: 0.9740631447775465.
# [I 2026-01-20 12:47:31,401] Trial 2 finished with value: 0.9723839208800242 and parameters: {'reg_lambda': 0.0006422942224949884, 'reg_alpha': 0.00010536086242992482, 'subsample': 0.5, 'colsample_bytree': 0.6373741552587293, 'n_estimators': 250, 'max_depth': 4, 'min_child_weight': 26, 'eta': 0.004219820958284576, 'gamma': 0.0735606085160289, 'grow_policy': 'depthwise', 'scale_pos_weight': 2.6699013725896448}. Best is trial 0 with value: 0.9740631447775465.
# [I 2026-01-20 12:47:57,075] Trial 3 finished with value: 0.972370053090732 and parameters: {'reg_lambda': 0.0006540626627670874, 'reg_alpha': 0.042486477961325236, 'subsample': 0.6, 'colsample_bytree': 0.8302686370282004, 'n_estimators': 750, 'max_depth': 8, 'min_child_weight': 28, 'eta': 0.12298884550069199, 'gamma': 0.16844982803149702, 'grow_policy': 'depthwise', 'scale_pos_weight': 6.815289160941177}. Best is trial 0 with value: 0.9740631447775465.
# [I 2026-01-20 12:48:17,690] Trial 4 finished with value: 0.9749572812365286 and parameters: {'reg_lambda': 0.026256500425297757, 'reg_alpha': 0.9910281500138097, 'subsample': 1.0, 'colsample_bytree': 0.5905841033204183, 'n_estimators': 550, 'max_depth': 8, 'min_child_weight': 23, 'eta': 0.001311448924840251, 'gamma': 0.0055100841511743276, 'grow_policy': 'depthwise', 'scale_pos_weight': 3.552968997387598}. Best is trial 4 with value: 0.9749572812365286.
# [I 2026-01-20 12:48:36,150] Trial 5 finished with value: 0.9789753398463218 and parameters: {'reg_lambda': 0.07826328527512014, 'reg_alpha': 0.0002463783457834548, 'subsample': 0.9, 'colsample_bytree': 0.3059871166726099, 'n_estimators': 450, 'max_depth': 4, 'min_child_weight': 23, 'eta': 0.027370917924850066, 'gamma': 0.25048897339126325, 'grow_policy': 'lossguide', 'scale_pos_weight': 7.195850182826579}. Best is trial 5 with value: 0.9789753398463218.
# [I 2026-01-20 12:48:54,978] Trial 6 finished with value: 0.9755285609793956 and parameters: {'reg_lambda': 0.07786344880127094, 'reg_alpha': 0.03317822075903322, 'subsample': 1.0, 'colsample_bytree': 0.9246050684325409, 'n_estimators': 350, 'max_depth': 8, 'min_child_weight': 26, 'eta': 0.1643967320717337, 'gamma': 0.10427736838217079, 'grow_policy': 'depthwise', 'scale_pos_weight': 6.778304579689354}. Best is trial 5 with value: 0.9789753398463218.
# [I 2026-01-20 12:49:14,732] Trial 7 finished with value: 0.9590527939817579 and parameters: {'reg_lambda': 0.23339130973893146, 'reg_alpha': 0.00108304699799007, 'subsample': 0.5, 'colsample_bytree': 0.9407403506012513, 'n_estimators': 750, 'max_depth': 2, 'min_child_weight': 19, 'eta': 0.001592294794518147, 'gamma': 0.0015753826961806307, 'grow_policy': 'lossguide', 'scale_pos_weight': 2.209715442136274}. Best is trial 5 with value: 0.9789753398463218.
# [I 2026-01-20 12:49:31,578] Trial 8 finished with value: 0.9724021758650853 and parameters: {'reg_lambda': 0.00021122464866571287, 'reg_alpha': 0.05883987301348522, 'subsample': 0.7, 'colsample_bytree': 0.7647246338201585, 'n_estimators': 150, 'max_depth': 4, 'min_child_weight': 6, 'eta': 0.008339037706274519, 'gamma': 0.46433941518380384, 'grow_policy': 'lossguide', 'scale_pos_weight': 2.0195082026574314}. Best is trial 5 with value: 0.9789753398463218.
# [I 2026-01-20 12:49:48,307] Trial 9 finished with value: 0.9787686365426314 and parameters: {'reg_lambda': 0.02077165410172024, 'reg_alpha': 0.012435460507550991, 'subsample': 0.9, 'colsample_bytree': 0.3386406179947031, 'n_estimators': 100, 'max_depth': 4, 'min_child_weight': 23, 'eta': 0.40126166073121095, 'gamma': 0.005329364795520369, 'grow_policy': 'lossguide', 'scale_pos_weight': 1.2215850347992774}. Best is trial 5 with value: 0.9789753398463218.
# [I 2026-01-20 12:50:06,809] Trial 10 finished with value: 0.977591375636434 and parameters: {'reg_lambda': 0.6903060762613779, 'reg_alpha': 0.00010148790664472562, 'subsample': 0.9, 'colsample_bytree': 0.22271040389444036, 'n_estimators': 400, 'max_depth': 6, 'min_child_weight': 11, 'eta': 0.030770306281243186, 'gamma': 0.8287116505595773, 'grow_policy': 'lossguide', 'scale_pos_weight': 9.990664224583956}. Best is trial 5 with value: 0.9789753398463218.
# [I 2026-01-20 12:50:23,544] Trial 11 finished with value: 0.97691131522988 and parameters: {'reg_lambda': 0.005104091514982806, 'reg_alpha': 0.0013638836287398703, 'subsample': 0.9, 'colsample_bytree': 0.4094691137075191, 'n_estimators': 150, 'max_depth': 4, 'min_child_weight': 30, 'eta': 0.03288011492499544, 'gamma': 0.014192027516973467, 'grow_policy': 'lossguide', 'scale_pos_weight': 4.692481207088583}. Best is trial 5 with value: 0.9789753398463218.
# [I 2026-01-20 12:50:42,095] Trial 12 finished with value: 0.9782031792669987 and parameters: {'reg_lambda': 0.005716946386106459, 'reg_alpha': 0.005525124613426935, 'subsample': 0.9, 'colsample_bytree': 0.2056532116571771, 'n_estimators': 600, 'max_depth': 4, 'min_child_weight': 22, 'eta': 0.605250389352409, 'gamma': 0.0157881882442083, 'grow_policy': 'lossguide', 'scale_pos_weight': 5.056880509622742}. Best is trial 5 with value: 0.9789753398463218.
# [I 2026-01-20 12:50:59,043] Trial 13 finished with value: 0.9765065875086251 and parameters: {'reg_lambda': 0.014435506918569284, 'reg_alpha': 0.0007974982545435786, 'subsample': 0.8, 'colsample_bytree': 0.4587157403216332, 'n_estimators': 300, 'max_depth': 2, 'min_child_weight': 17, 'eta': 0.03614033174937648, 'gamma': 0.00132730974059365, 'grow_policy': 'lossguide', 'scale_pos_weight': 7.868489794865015}. Best is trial 5 with value: 0.9789753398463218.
# [I 2026-01-20 12:51:15,620] Trial 14 finished with value: 0.9788725820767183 and parameters: {'reg_lambda': 0.0023482607601642913, 'reg_alpha': 0.3338432587762895, 'subsample': 0.9, 'colsample_bytree': 0.3291998852643916, 'n_estimators': 100, 'max_depth': 6, 'min_child_weight': 13, 'eta': 0.10307544193573782, 'gamma': 0.004097919822382867, 'grow_policy': 'lossguide', 'scale_pos_weight': 4.164228362630308}. Best is trial 5 with value: 0.9789753398463218.
# [I 2026-01-20 12:51:33,618] Trial 15 finished with value: 0.9789581905717993 and parameters: {'reg_lambda': 0.0029318965686009964, 'reg_alpha': 0.5033488399226597, 'subsample': 1.0, 'colsample_bytree': 0.47852600768515685, 'n_estimators': 250, 'max_depth': 6, 'min_child_weight': 12, 'eta': 0.07841819997697148, 'gamma': 0.03681840381734699, 'grow_policy': 'lossguide', 'scale_pos_weight': 4.035367252433662}. Best is trial 5 with value: 0.9789753398463218.
# [I 2026-01-20 12:51:52,442] Trial 16 finished with value: 0.9790393634458326 and parameters: {'reg_lambda': 0.2434955115419994, 'reg_alpha': 0.2022534246726757, 'subsample': 1.0, 'colsample_bytree': 0.522393235488977, 'n_estimators': 450, 'max_depth': 6, 'min_child_weight': 2, 'eta': 0.014450352917958119, 'gamma': 0.0431872852623662, 'grow_policy': 'lossguide', 'scale_pos_weight': 5.999712563801416}. Best is trial 16 with value: 0.9790393634458326.
# [I 2026-01-20 12:52:10,462] Trial 17 finished with value: 0.9789332381016143 and parameters: {'reg_lambda': 0.2585188643977475, 'reg_alpha': 0.19952208333366533, 'subsample': 1.0, 'colsample_bytree': 0.5723082505949872, 'n_estimators': 450, 'max_depth': 6, 'min_child_weight': 2, 'eta': 0.012850165656848272, 'gamma': 0.4236281249775627, 'grow_policy': 'lossguide', 'scale_pos_weight': 8.174660948569679}. Best is trial 16 with value: 0.9790393634458326.
# [I 2026-01-20 12:52:29,722] Trial 18 finished with value: 0.9793167185591061 and parameters: {'reg_lambda': 0.9187635073666874, 'reg_alpha': 0.0003120348325121934, 'subsample': 0.8, 'colsample_bytree': 0.51699401347579, 'n_estimators': 600, 'max_depth': 6, 'min_child_weight': 6, 'eta': 0.015826640197372458, 'gamma': 0.03360203518789633, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.925661865387361}. Best is trial 18 with value: 0.9793167185591061.
# [I 2026-01-20 12:52:52,799] Trial 19 finished with value: 0.9773867505843034 and parameters: {'reg_lambda': 0.9673293414910138, 'reg_alpha': 0.1349424270869294, 'subsample': 0.6, 'colsample_bytree': 0.5306628688485399, 'n_estimators': 650, 'max_depth': 8, 'min_child_weight': 2, 'eta': 0.0032577394612822845, 'gamma': 0.04111286310925181, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.784941760969169}. Best is trial 18 with value: 0.9793167185591061.
# [I 2026-01-20 12:53:13,870] Trial 20 finished with value: 0.9789909112638345 and parameters: {'reg_lambda': 0.3080462491979344, 'reg_alpha': 0.012531514707241936, 'subsample': 0.8, 'colsample_bytree': 0.6526773125780895, 'n_estimators': 600, 'max_depth': 6, 'min_child_weight': 7, 'eta': 0.009659718493682851, 'gamma': 0.020245543100177454, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.732001313005494}. Best is trial 18 with value: 0.9793167185591061.
# [I 2026-01-20 12:53:37,292] Trial 21 finished with value: 0.9793091864104915 and parameters: {'reg_lambda': 0.2539514061109692, 'reg_alpha': 0.017450042714273493, 'subsample': 0.7, 'colsample_bytree': 0.6708630839118644, 'n_estimators': 600, 'max_depth': 6, 'min_child_weight': 7, 'eta': 0.014200226642292245, 'gamma': 0.017045107958565738, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.860606188266961}. Best is trial 18 with value: 0.9793167185591061.
# [I 2026-01-20 12:53:58,031] Trial 22 finished with value: 0.9793264063052124 and parameters: {'reg_lambda': 0.4888289700384205, 'reg_alpha': 0.00331146558788939, 'subsample': 0.7, 'colsample_bytree': 0.6811436274444568, 'n_estimators': 550, 'max_depth': 6, 'min_child_weight': 6, 'eta': 0.017209097678644078, 'gamma': 0.009800045183122752, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.737139455137337}. Best is trial 22 with value: 0.9793264063052124.
# [I 2026-01-20 12:54:18,112] Trial 23 finished with value: 0.9793350650141385 and parameters: {'reg_lambda': 0.545869089392124, 'reg_alpha': 0.0020263928016497914, 'subsample': 0.7, 'colsample_bytree': 0.6909786389555144, 'n_estimators': 550, 'max_depth': 6, 'min_child_weight': 8, 'eta': 0.016588920932833935, 'gamma': 0.008323663004173818, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.170654499331588}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:54:40,171] Trial 24 finished with value: 0.9759879937968079 and parameters: {'reg_lambda': 0.5318178890509545, 'reg_alpha': 0.002516493754542775, 'subsample': 0.6, 'colsample_bytree': 0.7394292541236549, 'n_estimators': 550, 'max_depth': 8, 'min_child_weight': 9, 'eta': 0.051860239288919245, 'gamma': 0.008122158958668498, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.059179330100421}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:55:02,322] Trial 25 finished with value: 0.9786611304053863 and parameters: {'reg_lambda': 0.14095156279136173, 'reg_alpha': 0.00036227434256462515, 'subsample': 0.7, 'colsample_bytree': 0.8342583387223715, 'n_estimators': 800, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.020916585995587433, 'gamma': 0.0022661897208619388, 'grow_policy': 'depthwise', 'scale_pos_weight': 3.3449043897810347}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:55:23,070] Trial 26 finished with value: 0.9754015656850467 and parameters: {'reg_lambda': 0.9536430217477939, 'reg_alpha': 0.0003512883959080527, 'subsample': 0.8, 'colsample_bytree': 0.7155600160977993, 'n_estimators': 650, 'max_depth': 6, 'min_child_weight': 9, 'eta': 0.0027280713066559622, 'gamma': 0.008906711665607983, 'grow_policy': 'depthwise', 'scale_pos_weight': 4.460380930599194}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:55:43,516] Trial 27 finished with value: 0.978667447214011 and parameters: {'reg_lambda': 0.542450072054627, 'reg_alpha': 0.0026236077682476907, 'subsample': 0.6, 'colsample_bytree': 0.8160194179979001, 'n_estimators': 500, 'max_depth': 8, 'min_child_weight': 5, 'eta': 0.006829326612234686, 'gamma': 0.0034912904467925407, 'grow_policy': 'depthwise', 'scale_pos_weight': 7.94039609218174}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:56:04,107] Trial 28 finished with value: 0.9774678851216574 and parameters: {'reg_lambda': 0.5041136658378795, 'reg_alpha': 0.0005581236122563891, 'subsample': 0.7, 'colsample_bytree': 0.9915237529762657, 'n_estimators': 550, 'max_depth': 6, 'min_child_weight': 10, 'eta': 0.0485111984534191, 'gamma': 0.010082206890288997, 'grow_policy': 'depthwise', 'scale_pos_weight': 6.333528704197177}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:56:24,927] Trial 29 finished with value: 0.9792216348510878 and parameters: {'reg_lambda': 0.12336671761218616, 'reg_alpha': 0.0022774054170554866, 'subsample': 0.8, 'colsample_bytree': 0.6910024151595862, 'n_estimators': 700, 'max_depth': 6, 'min_child_weight': 14, 'eta': 0.01778964334337292, 'gamma': 0.02230777179056303, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.259565644719139}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:56:45,242] Trial 30 finished with value: 0.9755664867163568 and parameters: {'reg_lambda': 0.04235370772366546, 'reg_alpha': 0.005637228202779726, 'subsample': 0.8, 'colsample_bytree': 0.6035782250174275, 'n_estimators': 650, 'max_depth': 4, 'min_child_weight': 4, 'eta': 0.21527570860669157, 'gamma': 0.058538842482668135, 'grow_policy': 'depthwise', 'scale_pos_weight': 7.23790180448466}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:57:05,240] Trial 31 finished with value: 0.9791319250038995 and parameters: {'reg_lambda': 0.3417139838048889, 'reg_alpha': 0.00805466080367942, 'subsample': 0.7, 'colsample_bytree': 0.6718663425741821, 'n_estimators': 600, 'max_depth': 6, 'min_child_weight': 8, 'eta': 0.01075984685395268, 'gamma': 0.023599869366451493, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.42997466904141}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:57:24,418] Trial 32 finished with value: 0.9793323814465904 and parameters: {'reg_lambda': 0.11993574587514089, 'reg_alpha': 0.01858546211806219, 'subsample': 0.7, 'colsample_bytree': 0.7864174772322875, 'n_estimators': 500, 'max_depth': 6, 'min_child_weight': 7, 'eta': 0.019042414025977634, 'gamma': 0.012617290149535929, 'grow_policy': 'depthwise', 'scale_pos_weight': 6.29542246515265}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:57:43,365] Trial 33 finished with value: 0.9772917744880166 and parameters: {'reg_lambda': 0.1389989948543479, 'reg_alpha': 0.024528377234599063, 'subsample': 0.7, 'colsample_bytree': 0.7927030732054505, 'n_estimators': 500, 'max_depth': 6, 'min_child_weight': 4, 'eta': 0.006710536721919189, 'gamma': 0.010583919945820424, 'grow_policy': 'depthwise', 'scale_pos_weight': 6.413766386606349}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:58:02,727] Trial 34 finished with value: 0.9792065362526193 and parameters: {'reg_lambda': 0.4348823628803512, 'reg_alpha': 0.000197072918588204, 'subsample': 0.6, 'colsample_bytree': 0.863854784269662, 'n_estimators': 500, 'max_depth': 6, 'min_child_weight': 16, 'eta': 0.02273353487306886, 'gamma': 0.002650315711460222, 'grow_policy': 'depthwise', 'scale_pos_weight': 7.1106196356113855}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:58:22,385] Trial 35 finished with value: 0.976932432014419 and parameters: {'reg_lambda': 0.13470523274582166, 'reg_alpha': 0.0035100280486452654, 'subsample': 0.8, 'colsample_bytree': 0.6244884170802287, 'n_estimators': 400, 'max_depth': 8, 'min_child_weight': 11, 'eta': 0.004543108622719543, 'gamma': 0.0970683687255628, 'grow_policy': 'depthwise', 'scale_pos_weight': 6.3056667451639274}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:58:41,140] Trial 36 finished with value: 0.978333037033399 and parameters: {'reg_lambda': 0.726064079296291, 'reg_alpha': 0.001225216948361142, 'subsample': 0.5, 'colsample_bytree': 0.7602423162190927, 'n_estimators': 550, 'max_depth': 4, 'min_child_weight': 8, 'eta': 0.06740788269339153, 'gamma': 0.006527610877890491, 'grow_policy': 'depthwise', 'scale_pos_weight': 8.825140748200216}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:59:00,826] Trial 37 finished with value: 0.9791660924011467 and parameters: {'reg_lambda': 0.05571767053369276, 'reg_alpha': 0.008462363316895405, 'subsample': 0.7, 'colsample_bytree': 0.5544344906599508, 'n_estimators': 400, 'max_depth': 6, 'min_child_weight': 4, 'eta': 0.01902052424176242, 'gamma': 0.02874189896855977, 'grow_policy': 'depthwise', 'scale_pos_weight': 3.683294420158689}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:59:23,420] Trial 38 finished with value: 0.9753867139209866 and parameters: {'reg_lambda': 0.09616413410770405, 'reg_alpha': 0.0017717110547741915, 'subsample': 0.6, 'colsample_bytree': 0.8660203042371587, 'n_estimators': 700, 'max_depth': 8, 'min_child_weight': 7, 'eta': 0.04159893005595483, 'gamma': 0.01187214060983241, 'grow_policy': 'depthwise', 'scale_pos_weight': 4.723143414756208}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 12:59:46,061] Trial 39 finished with value: 0.9787741563518715 and parameters: {'reg_lambda': 0.1906379966691713, 'reg_alpha': 0.0006004020354315143, 'subsample': 0.7, 'colsample_bytree': 0.7187754815302373, 'n_estimators': 700, 'max_depth': 8, 'min_child_weight': 10, 'eta': 0.005877914039079408, 'gamma': 0.057923063190718924, 'grow_policy': 'depthwise', 'scale_pos_weight': 7.4384176980341525}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 13:00:03,941] Trial 40 finished with value: 0.9723118358166956 and parameters: {'reg_lambda': 0.03371382751217775, 'reg_alpha': 0.00015470291448295212, 'subsample': 0.8, 'colsample_bytree': 0.47345409058023474, 'n_estimators': 350, 'max_depth': 4, 'min_child_weight': 6, 'eta': 0.0022778607063374703, 'gamma': 0.0059081384595702, 'grow_policy': 'depthwise', 'scale_pos_weight': 6.622242249069767}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 13:00:23,099] Trial 41 finished with value: 0.979232548025784 and parameters: {'reg_lambda': 0.42036400487708603, 'reg_alpha': 0.014550696265759886, 'subsample': 0.7, 'colsample_bytree': 0.6397393883864743, 'n_estimators': 500, 'max_depth': 6, 'min_child_weight': 7, 'eta': 0.014671906594319504, 'gamma': 0.016576260338381846, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.907444762468993}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 13:00:43,116] Trial 42 finished with value: 0.9790103963854985 and parameters: {'reg_lambda': 0.18346209895066026, 'reg_alpha': 0.017986548585282047, 'subsample': 0.7, 'colsample_bytree': 0.6845453367756872, 'n_estimators': 600, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.024781148916941997, 'gamma': 0.029900600462452052, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.485930708528634}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 13:01:02,165] Trial 43 finished with value: 0.9787079603405358 and parameters: {'reg_lambda': 0.7596914506487189, 'reg_alpha': 0.02170220606974136, 'subsample': 0.7, 'colsample_bytree': 0.78219467211695, 'n_estimators': 550, 'max_depth': 6, 'min_child_weight': 3, 'eta': 0.009092611905211776, 'gamma': 0.0073821598220145754, 'grow_policy': 'depthwise', 'scale_pos_weight': 6.800040004248376}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 13:01:22,890] Trial 44 finished with value: 0.979220280960994 and parameters: {'reg_lambda': 0.07907968676478828, 'reg_alpha': 0.0597168358033504, 'subsample': 0.7, 'colsample_bytree': 0.3945361825736247, 'n_estimators': 650, 'max_depth': 6, 'min_child_weight': 9, 'eta': 0.01423375187325395, 'gamma': 0.013579804478760208, 'grow_policy': 'depthwise', 'scale_pos_weight': 6.04201670477098}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 13:01:43,266] Trial 45 finished with value: 0.9789573451471356 and parameters: {'reg_lambda': 0.00012815543104419198, 'reg_alpha': 0.04021662101972611, 'subsample': 0.6, 'colsample_bytree': 0.6155416236439847, 'n_estimators': 600, 'max_depth': 6, 'min_child_weight': 6, 'eta': 0.028542496430977015, 'gamma': 0.004553202454820375, 'grow_policy': 'depthwise', 'scale_pos_weight': 4.714780036978222}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 13:02:02,192] Trial 46 finished with value: 0.9754515795822947 and parameters: {'reg_lambda': 0.3007768905832303, 'reg_alpha': 0.08975264572247228, 'subsample': 0.8, 'colsample_bytree': 0.7133689596029209, 'n_estimators': 450, 'max_depth': 6, 'min_child_weight': 13, 'eta': 0.004036000460105022, 'gamma': 0.018520846044666497, 'grow_policy': 'depthwise', 'scale_pos_weight': 5.291445251454192}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 13:02:21,771] Trial 47 finished with value: 0.9776806631075773 and parameters: {'reg_lambda': 0.5754680729836972, 'reg_alpha': 0.004925550349590039, 'subsample': 0.7, 'colsample_bytree': 0.9055302830323417, 'n_estimators': 550, 'max_depth': 4, 'min_child_weight': 18, 'eta': 0.011640881157978959, 'gamma': 0.0945753146693744, 'grow_policy': 'depthwise', 'scale_pos_weight': 2.991512988964321}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 13:02:39,898] Trial 48 finished with value: 0.9751755252258228 and parameters: {'reg_lambda': 0.01853385190843537, 'reg_alpha': 0.029747463192728446, 'subsample': 0.8, 'colsample_bytree': 0.5146498936514388, 'n_estimators': 750, 'max_depth': 2, 'min_child_weight': 11, 'eta': 0.008075508657123075, 'gamma': 0.0032329639717845328, 'grow_policy': 'depthwise', 'scale_pos_weight': 4.14374611612462}. Best is trial 23 with value: 0.9793350650141385.
# [I 2026-01-20 13:02:59,395] Trial 49 finished with value: 0.9778495644277971 and parameters: {'reg_lambda': 0.34322763295535874, 'reg_alpha': 0.0036370472794408767, 'subsample': 0.5, 'colsample_bytree': 0.5742247163109045, 'n_estimators': 500, 'max_depth': 6, 'min_child_weight': 20, 'eta': 0.062176377690839064, 'gamma': 0.05525421414111168, 'grow_policy': 'depthwise', 'scale_pos_weight': 4.954597401320741}. Best is trial 23 with value: 0.9793350650141385.
# Number of finished trials:  50
# Best trial:
#   Value: 0.9793350650141385
#   Params:
#     reg_lambda: 0.545869089392124
#     reg_alpha: 0.0020263928016497914
#     subsample: 0.7
#     colsample_bytree: 0.6909786389555144
#     n_estimators: 550
#     max_depth: 6
#     min_child_weight: 8
#     eta: 0.016588920932833935
#     gamma: 0.008323663004173818
#     grow_policy: depthwise
#     scale_pos_weight: 5.170654499331588

# %%
# Best parameters found by optuna
best_params = {
    'reg_lambda': 0.545869089392124,
    'reg_alpha': 0.0020263928016497914,
    'subsample': 0.7,
    'colsample_bytree': 0.6909786389555144,
    'n_estimators': 550,
    'max_depth': 6,
    'min_child_weight': 8,
    'eta': 0.016588920932833935,
    'gamma': 0.008323663004173818,
    'grow_policy': 'depthwise',
    'scale_pos_weight': 5.170654499331588
}

# %%
final_model = XGBClassifier(**best_params, random_state=SEED)

final_pipeline_classifier = create_classification_pipeline(final_model)

final_pipeline_classifier.fit(X, y)
# Out:
# 2026/01/20 14:39:15 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '01215ae547ce472b82dcf57c120b8366', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   ['age', 'bmi', 'HbA1c_level',
#                                                    'blood_glucose_level']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['gender',
#                                                    'smoking_history']),
#                                                  ('bin', 'passthrough',
#                                                   ['hypertension',
#                                                    'heart_disease'])])),
#                 ('classifier',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsampl...
#                                feature_types=None, feature_weights=None,
#                                gamma=0.008323663004173818,
#                                grow_policy='depthwise', importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=6, max_leaves=None, min_child_weight=8,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=550,
#                                n_jobs=None, ...))])

# %%
final_classifier = final_pipeline_classifier[-1]
final_transformer = final_pipeline_classifier[0]

# %% [markdown]
# <p>The feature importances show what was already noticed during the EDA: the features related to blood glucose levels are the ones with most predicting power.</p>

# %%
dict_feature_importances = {'feature':final_transformer.get_feature_names_out(), 'importance':final_classifier.feature_importances_}
df_feature_importances = pd.DataFrame.from_dict(dict_feature_importances).sort_values(by='importance',ascending=False)
df_feature_importances
# Out:
#                     feature  importance
# 2          num__HbA1c_level    0.534820
# 3  num__blood_glucose_level    0.266606
# 0                  num__age    0.072125
# 6         bin__hypertension    0.045493
# 7        bin__heart_disease    0.031500
# 1                  num__bmi    0.028587
# 5      cat__smoking_history    0.011734
# 4               cat__gender    0.009134

# %% [markdown]
# <h2>Serializing the model</h2>

# %%
# serializing the model so it can be used with the API

with open('diabetes_xgbmodel.pkl','wb') as model:
    pickle.dump(final_pipeline_classifier, model)
